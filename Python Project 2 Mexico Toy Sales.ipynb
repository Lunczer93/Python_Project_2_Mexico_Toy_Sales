# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime
import calendar

pd.set_option('display.max_rows', 25)
pd.set_option('display.max_columns', 25)
pd.set_option('display.width', 25)

# %%
df1 = pd.read_csv("D:\My commercial projects\Python\Mexico Toy Sales\inventory.csv")

# %% [markdown]
# #### Browsing files

# %%
import glob

# getting csv files from the folder MyProject
path = "D:\My commercial projects\Python\Mexico Toy Sales"

# read all the files with extension .csv
filenames = glob.glob(path + "\*.csv")
print('File names:', filenames)

# for loop to iterate all csv files
for file in filenames:
   # reading csv files
   print("Reading file = ",file)
   print(pd.read_csv(file))
# Out:
# File names: ['D:\\My commercial projects\\Python\\Mexico Toy Sales\\inventory.csv', 'D:\\My commercial projects\\Python\\Mexico Toy Sales\\products.csv', 'D:\\My commercial projects\\Python\\Mexico Toy Sales\\sales.csv', 'D:\\My commercial projects\\Python\\Mexico Toy Sales\\stores.csv']
# Reading file =  D:\My commercial projects\Python\Mexico Toy Sales\inventory.csv
#       Store_ID  \
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 1588        50
# 1589        50
# 1590        50
# 1591        50
# 1592        50
#
#       Product_ID  \
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ...          ...
# 1588          31
# 1589          32
# 1590          33
# 1591          34
# 1592          35
#
#       Stock_On_Hand
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
# [1593 rows x 3 columns]
# Reading file =  D:\My commercial projects\Python\Mexico Toy Sales\products.csv
#     Product_ID  \
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 30          31
# 31          32
# 32          33
# 33          34
# 34          35
#
#              Product_Name  \
# 0           Action Figure
# 1          Animal Figures
# 2         Barrel O' Slime
# 3        Chutes & Ladders
# 4        Classic Dominoes
# ..                    ...
# 30           Splash Balls
# 31  Supersoaker Water Gun
# 32             Teddy Bear
# 33              Toy Robot
# 34          Uno Card Game
#
#      Product_Category  \
# 0                Toys
# 1                Toys
# 2        Art & Crafts
# 3               Games
# 4               Games
# ..                ...
# 30  Sports & Outdoors
# 31  Sports & Outdoors
# 32               Toys
# 33        Electronics
# 34              Games
#
#    Product_Cost  \
# 0        $9.99
# 1        $9.99
# 2        $1.99
# 3        $9.99
# 4        $7.99
# ..          ...
# 30       $7.99
# 31      $11.99
# 32      $10.99
# 33      $20.99
# 34       $3.99
#
#    Product_Price
# 0        $15.99
# 1        $12.99
# 2         $3.99
# 3        $12.99
# 4         $9.99
# ..           ...
# 30        $8.99
# 31       $14.99
# 32       $12.99
# 33       $25.99
# 34        $7.99
#
# [35 rows x 5 columns]
# Reading file =  D:\My commercial projects\Python\Mexico Toy Sales\sales.csv
#         Sale_ID  \
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
# ...         ...
# 829257   829258
# 829258   829259
# 829259   829260
# 829260   829261
# 829261   829262
#
#               Date  \
# 0       2017-01-01
# 1       2017-01-01
# 2       2017-01-01
# 3       2017-01-01
# 4       2017-01-01
# ...            ...
# 829257  2018-09-30
# 829258  2018-09-30
# 829259  2018-09-30
# 829260  2018-09-30
# 829261  2018-09-30
#
#         Store_ID  \
# 0             24
# 1             28
# 2              6
# 3             48
# 4             44
# ...          ...
# 829257        24
# 829258        16
# 829259        22
# 829260        13
# 829261        32
#
#         Product_ID  \
# 0                4
# 1                1
# 2                8
# 3                7
# 4               18
# ...            ...
# 829257          19
# 829258          35
# 829259          19
# 829260           2
# 829261           6
#
#         Units
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 829257      1
# 829258      1
# 829259      1
# 829260      2
# 829261      1
#
# [829262 rows x 5 columns]
# Reading file =  D:\My commercial projects\Python\Mexico Toy Sales\stores.csv
#     Store_ID  \
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
# ..       ...
# 45        46
# 46        47
# 47        48
# 48        49
# 49        50
#
#                   Store_Name  \
# 0   Maven Toys Guadalajara 1
# 1     Maven Toys Monterrey 1
# 2   Maven Toys Guadalajara 2
# 3      Maven Toys Saltillo 1
# 4        Maven Toys La Paz 1
# ..                       ...
# 45  Maven Toys Guadalajara 4
# 46    Maven Toys Monterrey 4
# 47     Maven Toys Saltillo 2
# 48     Maven Toys Culiacan 1
# 49   Maven Toys Guanajuato 3
#
#      Store_City  \
# 0   Guadalajara
# 1     Monterrey
# 2   Guadalajara
# 3      Saltillo
# 4        La Paz
# ..          ...
# 45  Guadalajara
# 46    Monterrey
# 47     Saltillo
# 48     Culiacan
# 49   Guanajuato
#
#    Store_Location  \
# 0     Residential
# 1     Residential
# 2      Commercial
# 3        Downtown
# 4        Downtown
# ..            ...
# 45       Downtown
# 46     Commercial
# 47     Commercial
# 48       Downtown
# 49    Residential
#
#    Store_Open_Date
# 0       1992-09-18
# 1       1995-04-27
# 2       1999-12-27
# 3       2000-01-01
# 4       2001-05-31
# ..             ...
# 45      2015-10-31
# 46      2015-11-21
# 47      2016-03-23
# 48      2016-05-10
# 49      2016-05-18
#
# [50 rows x 5 columns]

# %%
import glob

# getting csv files from the folder MyProject
path = "D:\My commercial projects\Python\Mexico Toy Sales\Data Dictionary"

# read all the files with extension .csv
filenames = glob.glob(path + "\*.csv")
print('File names:', filenames)

# for loop to iterate all csv files
for file in filenames:
   # reading csv files
   print("Reading file = ",file)
   print(pd.read_csv(file))
# Out:
# File names: ['D:\\My commercial projects\\Python\\Mexico Toy Sales\\Data Dictionary\\inventory_data_dictionary.csv', 'D:\\My commercial projects\\Python\\Mexico Toy Sales\\Data Dictionary\\products_data_dictionary.csv', 'D:\\My commercial projects\\Python\\Mexico Toy Sales\\Data Dictionary\\sales_data_dictionary.csv', 'D:\\My commercial projects\\Python\\Mexico Toy Sales\\Data Dictionary\\stores_data_dictionary.csv']
# Reading file =  D:\My commercial projects\Python\Mexico Toy Sales\Data Dictionary\inventory_data_dictionary.csv
#            Field  \
# 0       Store_ID
# 1     Product_ID
# 2  Stock_On_Hand
#
#                                          Description
# 0                                           Store ID
# 1                                         Product ID
# 2  Stock quantity of the product in the store (in...
# Reading file =  D:\My commercial projects\Python\Mexico Toy Sales\Data Dictionary\products_data_dictionary.csv
#               Field  \
# 0        Product_ID
# 1      Product_Name
# 2  Product_Category
# 3      Product_Cost
# 4     Product_Price
#
#                    Description
# 0                   Product ID
# 1                 Product name
# 2             Product Category
# 3          Product cost ($USD)
# 4  Product retail price ($USD)
# Reading file =  D:\My commercial projects\Python\Mexico Toy Sales\Data Dictionary\sales_data_dictionary.csv
#         Field  \
# 0     Sale_ID
# 1        Date
# 2    Store_ID
# 3  Product_ID
# 4       Units
#
#                Description
# 0                  Sale ID
# 1  Date of the transaction
# 2                 Store ID
# 3               Product ID
# 4               Units sold
# Reading file =  D:\My commercial projects\Python\Mexico Toy Sales\Data Dictionary\stores_data_dictionary.csv
#              Field  \
# 0         Store_ID
# 1       Store_Name
# 2       Store_City
# 3   Store_Location
# 4  Store_Open_Date
#
#                                        Description
# 0                                         Store ID
# 1                                       Store name
# 2        City in Mexico where the store is located
# 3  Location in the city where the store is located
# 4                   Date when the store was opened

# %% [markdown]
# #### transfer .csv to dataframe

# %%
dfInventory = pd.read_csv('D:\My commercial projects\Python\Project 2\Datasets Mexico Toy Sales\inventory.csv', index_col=0)

dfInventory
# Out:
#           Product_ID  \
# Store_ID
# 1                  1
# 1                  2
# 1                  3
# 1                  4
# 1                  5
# ...              ...
# 50                31
# 50                32
# 50                33
# 50                34
# 50                35
#
#           Stock_On_Hand
# Store_ID
# 1                    27
# 1                     0
# 1                    32
# 1                     6
# 1                     0
# ...                 ...
# 50                   18
# 50                    9
# 50                    1
# 50                   17
# 50                    8
#
# [1593 rows x 2 columns]

# %%
dfProducts = pd.read_csv('D:\My commercial projects\Python\Project 2\Datasets Mexico Toy Sales\products.csv', index_col=0)

dfProducts
# Out:
#                      Product_Name  \
# Product_ID
# 1                   Action Figure
# 2                  Animal Figures
# 3                 Barrel O' Slime
# 4                Chutes & Ladders
# 5                Classic Dominoes
# ...                           ...
# 31                   Splash Balls
# 32          Supersoaker Water Gun
# 33                     Teddy Bear
# 34                      Toy Robot
# 35                  Uno Card Game
#
#              Product_Category  \
# Product_ID
# 1                        Toys
# 2                        Toys
# 3                Art & Crafts
# 4                       Games
# 5                       Games
# ...                       ...
# 31          Sports & Outdoors
# 32          Sports & Outdoors
# 33                       Toys
# 34                Electronics
# 35                      Games
#
#            Product_Cost  \
# Product_ID
# 1                $9.99
# 2                $9.99
# 3                $1.99
# 4                $9.99
# 5                $7.99
# ...                 ...
# 31               $7.99
# 32              $11.99
# 33              $10.99
# 34              $20.99
# 35               $3.99
#
#            Product_Price
# Product_ID
# 1                $15.99
# 2                $12.99
# 3                 $3.99
# 4                $12.99
# 5                 $9.99
# ...                  ...
# 31                $8.99
# 32               $14.99
# 33               $12.99
# 34               $25.99
# 35                $7.99
#
# [35 rows x 4 columns]

# %%
dfStores =  pd.read_csv('D:\My commercial projects\Python\Project 2\Datasets Mexico Toy Sales\stores.csv', index_col=0)

dfStores
# Out:
#                         Store_Name  \
# Store_ID
# 1         Maven Toys Guadalajara 1
# 2           Maven Toys Monterrey 1
# 3         Maven Toys Guadalajara 2
# 4            Maven Toys Saltillo 1
# 5              Maven Toys La Paz 1
# ...                            ...
# 46        Maven Toys Guadalajara 4
# 47          Maven Toys Monterrey 4
# 48           Maven Toys Saltillo 2
# 49           Maven Toys Culiacan 1
# 50         Maven Toys Guanajuato 3
#
#            Store_City  \
# Store_ID
# 1         Guadalajara
# 2           Monterrey
# 3         Guadalajara
# 4            Saltillo
# 5              La Paz
# ...               ...
# 46        Guadalajara
# 47          Monterrey
# 48           Saltillo
# 49           Culiacan
# 50         Guanajuato
#
#          Store_Location  \
# Store_ID
# 1           Residential
# 2           Residential
# 3            Commercial
# 4              Downtown
# 5              Downtown
# ...                 ...
# 46             Downtown
# 47           Commercial
# 48           Commercial
# 49             Downtown
# 50          Residential
#
#          Store_Open_Date
# Store_ID
# 1             1992-09-18
# 2             1995-04-27
# 3             1999-12-27
# 4             2000-01-01
# 5             2001-05-31
# ...                  ...
# 46            2015-10-31
# 47            2015-11-21
# 48            2016-03-23
# 49            2016-05-10
# 50            2016-05-18
#
# [50 rows x 4 columns]

# %% [markdown]
# #### Combing dataframe

# %%
dfMergedLeftStoredAndProductToInventory = dfInventory.merge(dfStores, how='left', on='Store_ID').merge(dfProducts, how= 'left', on ='Product_ID')

dfMergedLeftStoredAndProductToInventory
# Out:
#       Product_ID  \
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ...          ...
# 1588          31
# 1589          32
# 1590          33
# 1591          34
# 1592          35
#
#       Stock_On_Hand  \
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
#                     Store_Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store_City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store_Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store_Open_Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product_Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product_Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#      Product_Cost  \
# 0          $9.99
# 1          $9.99
# 2          $1.99
# 3          $9.99
# 4          $7.99
# ...           ...
# 1588       $7.99
# 1589      $11.99
# 1590      $10.99
# 1591      $20.99
# 1592       $3.99
#
#      Product_Price
# 0          $15.99
# 1          $12.99
# 2           $3.99
# 3          $12.99
# 4           $9.99
# ...            ...
# 1588        $8.99
# 1589       $14.99
# 1590       $12.99
# 1591       $25.99
# 1592        $7.99
#
# [1593 rows x 10 columns]

# %%
dfMergedLeftStoredAndProductToInventory.drop(columns='Product_ID', inplace=True)

# %% [markdown]
# #### change the position of column Stock_On_Hand

# %%
dfMergedLeftStoredAndProductToInventory
# Out:
#       Stock_On_Hand  \
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
#                     Store_Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store_City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store_Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store_Open_Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product_Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product_Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#      Product_Cost  \
# 0          $9.99
# 1          $9.99
# 2          $1.99
# 3          $9.99
# 4          $7.99
# ...           ...
# 1588       $7.99
# 1589      $11.99
# 1590      $10.99
# 1591      $20.99
# 1592       $3.99
#
#      Product_Price
# 0          $15.99
# 1          $12.99
# 2           $3.99
# 3          $12.99
# 4           $9.99
# ...            ...
# 1588        $8.99
# 1589       $14.99
# 1590       $12.99
# 1591       $25.99
# 1592        $7.99
#
# [1593 rows x 9 columns]

# %%
eigth_column = dfMergedLeftStoredAndProductToInventory.pop('Stock_On_Hand')

dfMergedLeftStoredAndProductToInventory.insert(8,'Stock_On_Hand',eigth_column )

dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store_Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store_City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store_Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store_Open_Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product_Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product_Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#      Product_Cost  \
# 0          $9.99
# 1          $9.99
# 2          $1.99
# 3          $9.99
# 4          $7.99
# ...           ...
# 1588       $7.99
# 1589      $11.99
# 1590      $10.99
# 1591      $20.99
# 1592       $3.99
#
#      Product_Price  \
# 0          $15.99
# 1          $12.99
# 2           $3.99
# 3          $12.99
# 4           $9.99
# ...            ...
# 1588        $8.99
# 1589       $14.99
# 1590       $12.99
# 1591       $25.99
# 1592        $7.99
#
#       Stock_On_Hand
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
# [1593 rows x 9 columns]

# %%
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store_Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store_City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store_Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store_Open_Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product_Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product_Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#      Product_Cost  \
# 0          $9.99
# 1          $9.99
# 2          $1.99
# 3          $9.99
# 4          $7.99
# ...           ...
# 1588       $7.99
# 1589      $11.99
# 1590      $10.99
# 1591      $20.99
# 1592       $3.99
#
#      Product_Price  \
# 0          $15.99
# 1          $12.99
# 2           $3.99
# 3          $12.99
# 4           $9.99
# ...            ...
# 1588        $8.99
# 1589       $14.99
# 1590       $12.99
# 1591       $25.99
# 1592        $7.99
#
#       Stock_On_Hand
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
# [1593 rows x 9 columns]

# %% [markdown]
# #### Renaming the name of column

# %%
for col in dfMergedLeftStoredAndProductToInventory.columns:
    print(col)
# Out:
# Store_Name
# Store_City
# Store_Location
# Store_Open_Date
# Product_Name
# Product_Category
# Product_Cost
# Product_Price
# Stock_On_Hand

# %%
dfMergedLeftStoredAndProductToInventory.rename(columns = 
                                              {
                                                'Store_Name': 'Store Name',
                                                'Store_City': 'Store City',
                                                'Store_Location': 'Store Location',
                                                'Store_Open_Date': 'Store Open Date',
                                                'Product_Name': 'Product Name',
                                                'Product_Category': 'Product Category',
                                                'Product_Cost': 'Product Cost ($)',
                                                'Product_Price': 'Product Price ($)',
                                                'Stock_On_Hand': 'Stock On Hand' 
                                                },
                                                   inplace=True)

# %%
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store Open Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#      Product Cost ($)  \
# 0              $9.99
# 1              $9.99
# 2              $1.99
# 3              $9.99
# 4              $7.99
# ...               ...
# 1588           $7.99
# 1589          $11.99
# 1590          $10.99
# 1591          $20.99
# 1592           $3.99
#
#      Product Price ($)  \
# 0              $15.99
# 1              $12.99
# 2               $3.99
# 3              $12.99
# 4               $9.99
# ...                ...
# 1588            $8.99
# 1589           $14.99
# 1590           $12.99
# 1591           $25.99
# 1592            $7.99
#
#       Stock On Hand
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
# [1593 rows x 9 columns]

# %%
dfMergedLeftStoredAndProductToInventory['Product Cost ($)'] = dfMergedLeftStoredAndProductToInventory['Product Cost ($)'].apply(lambda x:x.replace('$','')).astype('float')
dfMergedLeftStoredAndProductToInventory['Product Price ($)'] = dfMergedLeftStoredAndProductToInventory['Product Price ($)'].apply(lambda x:x.replace('$','')).astype('float')

# %%
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store Open Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#       Product Cost ($)  \
# 0                 9.99
# 1                 9.99
# 2                 1.99
# 3                 9.99
# 4                 7.99
# ...                ...
# 1588              7.99
# 1589             11.99
# 1590             10.99
# 1591             20.99
# 1592              3.99
#
#       Product Price ($)  \
# 0                 15.99
# 1                 12.99
# 2                  3.99
# 3                 12.99
# 4                  9.99
# ...                 ...
# 1588               8.99
# 1589              14.99
# 1590              12.99
# 1591              25.99
# 1592               7.99
#
#       Stock On Hand
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
# [1593 rows x 9 columns]

# %% [markdown]
# #### Data Cleaning

# %% [markdown]
# ##### Looking for NaN values

# %%
for col in dfMergedLeftStoredAndProductToInventory.columns:
    pct_missing = round(np.mean(dfMergedLeftStoredAndProductToInventory[col].isnull()),2)
    print('{}-{}%'.format(col, pct_missing))
# Out:
# Store Name-0.0%
# Store City-0.0%
# Store Location-0.0%
# Store Open Date-0.0%
# Product Name-0.0%
# Product Category-0.0%
# Product Cost ($)-0.0%
# Product Price ($)-0.0%
# Stock On Hand-0.0%

# %%
dfMergedLeftStoredAndProductToInventory= dfMergedLeftStoredAndProductToInventory.dropna()
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store Open Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#       Product Cost ($)  \
# 0                 9.99
# 1                 9.99
# 2                 1.99
# 3                 9.99
# 4                 7.99
# ...                ...
# 1588              7.99
# 1589             11.99
# 1590             10.99
# 1591             20.99
# 1592              3.99
#
#       Product Price ($)  \
# 0                 15.99
# 1                 12.99
# 2                  3.99
# 3                 12.99
# 4                  9.99
# ...                 ...
# 1588               8.99
# 1589              14.99
# 1590              12.99
# 1591              25.99
# 1592               7.99
#
#       Stock On Hand
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
# [1593 rows x 9 columns]

# %%
NaN_dfMergedLeftStoredAndProductToInventory = dfMergedLeftStoredAndProductToInventory[dfMergedLeftStoredAndProductToInventory.isna().any(axis=1)]
NaN_dfMergedLeftStoredAndProductToInventory.head()
# Out:
# Empty DataFrame
# Columns: [Store Name, Store City, Store Location, Store Open Date, Product Name, Product Category, Product Cost ($), Product Price ($), Stock On Hand]
# Index: []

# %%
dfMergedLeftStoredAndProductToInventory.isnull().sum()
# Out:
# Store Name           0
# Store City           0
# Store Location       0
# Store Open Date      0
# Product Name         0
# Product Category     0
# Product Cost ($)     0
# Product Price ($)    0
# Stock On Hand        0
# dtype: int64

# %% [markdown]
# ##### Looking for duplicates

# %%
dfMergedLeftStoredAndProductToInventory.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1588    False
# 1589    False
# 1590    False
# 1591    False
# 1592    False
# Length: 1593, dtype: bool

# %%
dfMergedLeftStoredAndProductToInventory.nunique()
# Out:
# Store Name           50
# Store City           29
# Store Location        4
# Store Open Date      50
# Product Name         35
# Product Category      5
# Product Cost ($)     16
# Product Price ($)    18
# Stock On Hand        93
# dtype: int64

# %%
dfMergedLeftStoredAndProductToInventoryDuplicate = dfMergedLeftStoredAndProductToInventory[dfMergedLeftStoredAndProductToInventory.duplicated()]

# %%
dfMergedLeftStoredAndProductToInventoryDuplicate
# Out:
# Empty DataFrame
# Columns: [Store Name, Store City, Store Location, Store Open Date, Product Name, Product Category, Product Cost ($), Product Price ($), Stock On Hand]
# Index: []

# %% [markdown]
# ##### EDA

# %%
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store Open Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#       Product Cost ($)  \
# 0                 9.99
# 1                 9.99
# 2                 1.99
# 3                 9.99
# 4                 7.99
# ...                ...
# 1588              7.99
# 1589             11.99
# 1590             10.99
# 1591             20.99
# 1592              3.99
#
#       Product Price ($)  \
# 0                 15.99
# 1                 12.99
# 2                  3.99
# 3                 12.99
# 4                  9.99
# ...                 ...
# 1588               8.99
# 1589              14.99
# 1590              12.99
# 1591              25.99
# 1592               7.99
#
#       Stock On Hand
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
# [1593 rows x 9 columns]

# %%
dfMergedLeftStoredAndProductToInventory.dtypes
# Out:
# Store Name            object
# Store City            object
# Store Location        object
# Store Open Date       object
# Product Name          object
# Product Category      object
# Product Cost ($)     float64
# Product Price ($)    float64
# Stock On Hand          int64
# dtype: object

# %%
for col in dfMergedLeftStoredAndProductToInventory.columns:
    print(col)
# Out:
# Store Name
# Store City
# Store Location
# Store Open Date
# Product Name
# Product Category
# Product Cost ($)
# Product Price ($)
# Stock On Hand

# %%
dfMergedLeftStoredAndProductToInventory['Store Open Date'] = dfMergedLeftStoredAndProductToInventory['Store Open Date'].apply(pd.to_datetime)

# %%
dfMergedLeftStoredAndProductToInventory.dtypes
# Out:
# Store Name                   object
# Store City                   object
# Store Location               object
# Store Open Date      datetime64[ns]
# Product Name                 object
# Product Category             object
# Product Cost ($)            float64
# Product Price ($)           float64
# Stock On Hand                 int64
# dtype: object

# %%
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store Open Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#       Product Cost ($)  \
# 0                 9.99
# 1                 9.99
# 2                 1.99
# 3                 9.99
# 4                 7.99
# ...                ...
# 1588              7.99
# 1589             11.99
# 1590             10.99
# 1591             20.99
# 1592              3.99
#
#       Product Price ($)  \
# 0                 15.99
# 1                 12.99
# 2                  3.99
# 3                 12.99
# 4                  9.99
# ...                 ...
# 1588               8.99
# 1589              14.99
# 1590              12.99
# 1591              25.99
# 1592               7.99
#
#       Stock On Hand
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
# [1593 rows x 9 columns]

# %% [markdown]
# ##### Calculating Gross Profit ($)

# %%
dfMergedLeftStoredAndProductToInventory['Gross Profit ($)'] = dfMergedLeftStoredAndProductToInventory['Product Price ($)'] - dfMergedLeftStoredAndProductToInventory['Product Cost ($)']

# %%
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store Open Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#       Product Cost ($)  \
# 0                 9.99
# 1                 9.99
# 2                 1.99
# 3                 9.99
# 4                 7.99
# ...                ...
# 1588              7.99
# 1589             11.99
# 1590             10.99
# 1591             20.99
# 1592              3.99
#
#       Product Price ($)  \
# 0                 15.99
# 1                 12.99
# 2                  3.99
# 3                 12.99
# 4                  9.99
# ...                 ...
# 1588               8.99
# 1589              14.99
# 1590              12.99
# 1591              25.99
# 1592               7.99
#
#       Stock On Hand  \
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
#       Gross Profit ($)
# 0                  6.0
# 1                  3.0
# 2                  2.0
# 3                  3.0
# 4                  2.0
# ...                ...
# 1588               1.0
# 1589               3.0
# 1590               2.0
# 1591               5.0
# 1592               4.0
#
# [1593 rows x 10 columns]

# %% [markdown]
# ##### Analysis of Store City and Stock On Hand, then visualize it

# %%
dfMergedLeftStoredAndProductToInventory['Store City'].unique()
# Out:
# array(['Guadalajara', 'Monterrey', 'Saltillo', 'La Paz', 'Mexicali',
#        'Pachuca', 'Cuidad de Mexico', 'Campeche', 'Cuernavaca',
#        'Chetumal', 'Guanajuato', 'Tuxtla Gutierrez', 'San Luis Potosi',
#        'Toluca', 'Merida', 'Puebla', 'Zacatecas', 'Santiago', 'Chihuahua',
#        'Aguascalientes', 'Ciudad Victoria', 'Oaxaca', 'Xalapa',
#        'Hermosillo', 'Villahermosa', 'Chilpancingo', 'Morelia', 'Durango',
#        'Culiacan'], dtype=object)

# %%
dfMergedLeftStoredAndProductToInventory['Store Name'].unique()
# Out:
# array(['Maven Toys Guadalajara 1', 'Maven Toys Monterrey 1',
#        'Maven Toys Guadalajara 2', 'Maven Toys Saltillo 1',
#        'Maven Toys La Paz 1', 'Maven Toys Mexicali 1',
#        'Maven Toys Monterrey 2', 'Maven Toys Pachuca 1',
#        'Maven Toys Ciudad de Mexico 1', 'Maven Toys Campeche 1',
#        'Maven Toys Cuernavaca 1', 'Maven Toys Chetumal 1',
#        'Maven Toys Mexicali 2', 'Maven Toys Guanajuato 1',
#        'Maven Toys Tuxtla Gutierrez 1', 'Maven Toys San Luis Potosi 1',
#        'Maven Toys Toluca 1', 'Maven Toys Merida 1',
#        'Maven Toys Puebla 1', 'Maven Toys Zacatecas 1',
#        'Maven Toys Santiago 1', 'Maven Toys Guanajuato 2',
#        'Maven Toys Chihuahua 1', 'Maven Toys Aguascalientes 1',
#        'Maven Toys Ciudad Victoria 1', 'Maven Toys Campeche 2',
#        'Maven Toys Oaxaca 1', 'Maven Toys Puebla 2',
#        'Maven Toys Xalapa 1', 'Maven Toys Guadalajara 3',
#        'Maven Toys Ciudad de Mexico 2', 'Maven Toys Hermosillo 1',
#        'Maven Toys Monterrey 3', 'Maven Toys Villahermosa 1',
#        'Maven Toys Chilpancingo 1', 'Maven Toys Morelia 1',
#        'Maven Toys Ciudad de Mexico 3', 'Maven Toys Chihuahua 2',
#        'Maven Toys Xalapa 2', 'Maven Toys Toluca 2',
#        'Maven Toys Hermosillo 2', 'Maven Toys Hermosillo 3',
#        'Maven Toys Durango 1', 'Maven Toys Puebla 3',
#        'Maven Toys Ciudad de Mexico 4', 'Maven Toys Guadalajara 4',
#        'Maven Toys Monterrey 4', 'Maven Toys Saltillo 2',
#        'Maven Toys Culiacan 1', 'Maven Toys Guanajuato 3'], dtype=object)

# %%
dfMergedLeftStoredAndProductToInventory['Store Location'].unique()
# Out:
# array(['Residential', 'Commercial', 'Downtown', 'Airport'], dtype=object)

# %%
Top3StoreCityStockOnHand = dfMergedLeftStoredAndProductToInventory.groupby('Store City')['Stock On Hand'].agg('sum').to_frame()
Top3StoreCityStockOnHand.nlargest(3,'Stock On Hand')
# Out:
#                   Stock On Hand
# Store City
# Cuidad de Mexico           2681
# Guadalajara                2331
# Hermosillo                 2232

# %%
StoreCities = ['Cuidad de Mexico','Guadalajara','Hermosillo',]
Top3StoreCityStockOnHand.loc[StoreCities]
# Out:
#                   Stock On Hand
# Store City
# Cuidad de Mexico           2681
# Guadalajara                2331
# Hermosillo                 2232

# %%
Top3ProductCategory=dfMergedLeftStoredAndProductToInventory.groupby(['Store City','Product Category'])['Stock On Hand'].agg("sum").to_frame()
CuidadDeMexico=Top3ProductCategory.loc['Cuidad de Mexico'].sort_values(by='Stock On Hand',ascending=False).reset_index()
CuidadDeMexico
# Out:
#     Product Category  \
# 0       Art & Crafts
# 1               Toys
# 2              Games
# 3  Sports & Outdoors
# 4        Electronics
#
#    Stock On Hand
# 0            833
# 1            716
# 2            503
# 3            393
# 4            236

# %%
x = CuidadDeMexico['Stock On Hand']
label = CuidadDeMexico['Product Category']
explode = (0.1, 0, 0, 0, 0) 
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#fff266']
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use("fivethirtyeight")
plt.pie(x,explode=explode,labels=label,colors=colors, shadow=True,
       startangle=90, autopct='%1.1f%%', wedgeprops={'edgecolor': 'black',
                                                    'linewidth': 0.01,
                                                    'antialiased':True})

plt.title("Stock On Hand Product Category Cuidad de Mexico", fontsize=19)

plt.tight_layout()
plt.show()

# %%
Guadalajara=Top3ProductCategory.loc['Guadalajara'].sort_values(by='Stock On Hand',ascending=False).reset_index()
Guadalajara
# Out:
#     Product Category  \
# 0       Art & Crafts
# 1               Toys
# 2              Games
# 3  Sports & Outdoors
# 4        Electronics
#
#    Stock On Hand
# 0            672
# 1            622
# 2            482
# 3            279
# 4            276

# %%
x = Guadalajara['Stock On Hand']
label = Guadalajara['Product Category']
explode = (0.1, 0, 0, 0, 0) 
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use("tableau-colorblind10")
plt.pie(x,explode=explode,labels=label, shadow=True,
       startangle=90, autopct='%1.1f%%', wedgeprops={'edgecolor': 'black',
                                                    'linewidth': 0.01,
                                                    'antialiased':True})

plt.title("Stock On Hand Product Category Guadalajara", fontsize=19)

plt.tight_layout()
plt.show()

# %%
Hermosillo=Top3ProductCategory.loc['Hermosillo'].sort_values(by='Stock On Hand',ascending=False).reset_index()
Hermosillo
# Out:
#     Product Category  \
# 0               Toys
# 1       Art & Crafts
# 2              Games
# 3  Sports & Outdoors
# 4        Electronics
#
#    Stock On Hand
# 0            677
# 1            589
# 2            386
# 3            384
# 4            196

# %%
x = Hermosillo['Stock On Hand']
label = Hermosillo['Product Category']
explode = (0.1, 0, 0, 0, 0)

# %%
plt.style.use("seaborn-colorblind")
plt.pie(x,explode=explode,labels=label, shadow=True,
       startangle=90, autopct='%1.1f%%', wedgeprops={'edgecolor': 'black',
                                                    'linewidth': 0.01,
                                                    'antialiased':True})

plt.title("Stock On Hand Product Category Hermosillo", fontsize=19)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Grouping Store City by Stock On Hand with Ranking

# %%
StoreCityStockOnHand =dfMergedLeftStoredAndProductToInventory.groupby('Store City')['Stock On Hand'].agg('sum').to_frame()
StoreCityStockOnHandSorted = StoreCityStockOnHand.sort_values('Stock On Hand', ascending=False).reset_index()
StoreCityStockOnHandSorted
# Out:
#           Store City  \
# 0   Cuidad de Mexico
# 1        Guadalajara
# 2         Hermosillo
# 3          Monterrey
# 4         Guanajuato
# ..               ...
# 24   Ciudad Victoria
# 25           Durango
# 26         Zacatecas
# 27            Oaxaca
# 28            La Paz
#
#     Stock On Hand
# 0            2681
# 1            2331
# 2            2232
# 3            2227
# 4            1596
# ..            ...
# 24            546
# 25            526
# 26            480
# 27            479
# 28            473
#
# [29 rows x 2 columns]

# %%
def Ranking(x):
    if x < 500:
        return 'Low Stock'
    elif x < 1000:
        return 'Med Stock'
    elif x < 1500:
        return 'Med-High Stock'
    else:
        return 'High Stock'



StoreCityStockOnHandSorted["Ranking"] = StoreCityStockOnHandSorted["Stock On Hand"].apply(Ranking)

# %%
StoreCityStockOnHandSorted.set_index('Store City')
# Out:
#                   Stock On Hand  \
# Store City
# Cuidad de Mexico           2681
# Guadalajara                2331
# Hermosillo                 2232
# Monterrey                  2227
# Guanajuato                 1596
# ...                         ...
# Ciudad Victoria             546
# Durango                     526
# Zacatecas                   480
# Oaxaca                      479
# La Paz                      473
#
#                      Ranking
# Store City
# Cuidad de Mexico  High Stock
# Guadalajara       High Stock
# Hermosillo        High Stock
# Monterrey         High Stock
# Guanajuato        High Stock
# ...                      ...
# Ciudad Victoria    Med Stock
# Durango            Med Stock
# Zacatecas          Low Stock
# Oaxaca             Low Stock
# La Paz             Low Stock
#
# [29 rows x 2 columns]

# %% [markdown]
# ##### Visualising Stock on Hand by Product Name, then Ranking it

# %%
StockOnHandByProductName=dfMergedLeftStoredAndProductToInventory.groupby(['Product Name'])['Stock On Hand'].agg("sum").to_frame()
StockOnHandByProductNameSorted = StockOnHandByProductName.sort_values(by='Stock On Hand', ascending=False).reset_index()
StockOnHandByProductNameSorted
# Out:
#             Product Name  \
# 0          Deck Of Cards
# 1       Dinosaur Figures
# 2            PlayDoh Can
# 3             Magic Sand
# 4           Rubik's Cube
# ..                   ...
# 30      Classic Dominoes
# 31         Uno Card Game
# 32  Mini Basketball Hoop
# 33              Monopoly
# 34                 Jenga
#
#     Stock On Hand
# 0            2738
# 1            2272
# 2            2129
# 3            1922
# 4            1497
# ..            ...
# 30            241
# 31            241
# 32            234
# 33            207
# 34            181
#
# [35 rows x 2 columns]

# %%
x = StockOnHandByProductNameSorted['Product Name']
y = StockOnHandByProductNameSorted['Stock On Hand']


plt.bar(x, y)

plt.title('Stock On Hand by Product Name')
plt.xlabel('Product Name')
plt.ylabel('Quantity of Product Name')

plt.xticks(rotation=90)
plt.figure(figsize=(100, 50))



plt.show()

# %%
def RankingProductNameStockOnHand(x):
    if x <  500:
        return 'Low Level of Product in Stock'
    elif x <  1000:
        return 'Mid Level of Product in Stock'
    elif x < 1500:
        return 'Upper-Mid Level of Product in Stock'
    elif x < 2000:
        return 'High Level Of Product in Stock'
    else:
        return 'Upper High Level of Product in Stock'
    
    
StockOnHandByProductNameSorted['Ranking'] = StockOnHandByProductNameSorted['Stock On Hand'].apply(RankingProductNameStockOnHand)

# %%
StockOnHandByProductNameSorted
# Out:
#             Product Name  \
# 0          Deck Of Cards
# 1       Dinosaur Figures
# 2            PlayDoh Can
# 3             Magic Sand
# 4           Rubik's Cube
# ..                   ...
# 30      Classic Dominoes
# 31         Uno Card Game
# 32  Mini Basketball Hoop
# 33              Monopoly
# 34                 Jenga
#
#     Stock On Hand  \
# 0            2738
# 1            2272
# 2            2129
# 3            1922
# 4            1497
# ..            ...
# 30            241
# 31            241
# 32            234
# 33            207
# 34            181
#
#                                  Ranking
# 0   Upper High Level of Product in Stock
# 1   Upper High Level of Product in Stock
# 2   Upper High Level of Product in Stock
# 3         High Level Of Product in Stock
# 4    Upper-Mid Level of Product in Stock
# ..                                   ...
# 30         Low Level of Product in Stock
# 31         Low Level of Product in Stock
# 32         Low Level of Product in Stock
# 33         Low Level of Product in Stock
# 34         Low Level of Product in Stock
#
# [35 rows x 3 columns]

# %%
StockOnHandByProductNameSorted['Ranking'].value_counts()
# Out:
# Mid Level of Product in Stock           13
# Low Level of Product in Stock           12
# Upper-Mid Level of Product in Stock      6
# Upper High Level of Product in Stock     3
# High Level Of Product in Stock           1
# Name: Ranking, dtype: int64

# %% [markdown]
# ##### Quantity of Store Name in Store City

# %%
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store Open Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#       Product Cost ($)  \
# 0                 9.99
# 1                 9.99
# 2                 1.99
# 3                 9.99
# 4                 7.99
# ...                ...
# 1588              7.99
# 1589             11.99
# 1590             10.99
# 1591             20.99
# 1592              3.99
#
#       Product Price ($)  \
# 0                 15.99
# 1                 12.99
# 2                  3.99
# 3                 12.99
# 4                  9.99
# ...                 ...
# 1588               8.99
# 1589              14.99
# 1590              12.99
# 1591              25.99
# 1592               7.99
#
#       Stock On Hand  \
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
#       Gross Profit ($)
# 0                  6.0
# 1                  3.0
# 2                  2.0
# 3                  3.0
# 4                  2.0
# ...                ...
# 1588               1.0
# 1589               3.0
# 1590               2.0
# 1591               5.0
# 1592               4.0
#
# [1593 rows x 10 columns]

# %%
QuantityOfStoreInStoreCity = dfMergedLeftStoredAndProductToInventory.groupby(["Store City"])['Store Name'].nunique()
QuantityOfStoreInStoreCity.to_frame()
# Out:
#                   Store Name
# Store City
# Aguascalientes             1
# Campeche                   2
# Chetumal                   1
# Chihuahua                  2
# Chilpancingo               1
# ...                      ...
# Toluca                     2
# Tuxtla Gutierrez           1
# Villahermosa               1
# Xalapa                     2
# Zacatecas                  1
#
# [29 rows x 1 columns]

# %%
GroupingStoreCityByStoreName=dfMergedLeftStoredAndProductToInventory.groupby(["Store City",'Store Name'])["Stock On Hand"].sum()
GroupingStoreCityByStoreName.to_frame()
# Out:
#                                                 Stock On Hand
# Store City       Store Name
# Aguascalientes   Maven Toys Aguascalientes 1              654
# Campeche         Maven Toys Campeche 1                    657
#                  Maven Toys Campeche 2                    581
# Chetumal         Maven Toys Chetumal 1                    656
# Chihuahua        Maven Toys Chihuahua 1                   604
# ...                                                       ...
# Tuxtla Gutierrez Maven Toys Tuxtla Gutierrez 1            574
# Villahermosa     Maven Toys Villahermosa 1                722
# Xalapa           Maven Toys Xalapa 1                      435
#                  Maven Toys Xalapa 2                      502
# Zacatecas        Maven Toys Zacatecas 1                   480
#
# [50 rows x 1 columns]

# %% [markdown]
# ##### Analysis of Opening Date

# %%
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store Open Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#       Product Cost ($)  \
# 0                 9.99
# 1                 9.99
# 2                 1.99
# 3                 9.99
# 4                 7.99
# ...                ...
# 1588              7.99
# 1589             11.99
# 1590             10.99
# 1591             20.99
# 1592              3.99
#
#       Product Price ($)  \
# 0                 15.99
# 1                 12.99
# 2                  3.99
# 3                 12.99
# 4                  9.99
# ...                 ...
# 1588               8.99
# 1589              14.99
# 1590              12.99
# 1591              25.99
# 1592               7.99
#
#       Stock On Hand  \
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
#       Gross Profit ($)
# 0                  6.0
# 1                  3.0
# 2                  2.0
# 3                  3.0
# 4                  2.0
# ...                ...
# 1588               1.0
# 1589               3.0
# 1590               2.0
# 1591               5.0
# 1592               4.0
#
# [1593 rows x 10 columns]

# %% [markdown]
# #####  Extraction of Year from a Store Open Date column, then visualising how many stores were opened in a particular year

# %%
dfMergedLeftStoredAndProductToInventory['Year Of Store Open Date'] = pd.DatetimeIndex(dfMergedLeftStoredAndProductToInventory['Store Open Date']).year
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store Open Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#       Product Cost ($)  \
# 0                 9.99
# 1                 9.99
# 2                 1.99
# 3                 9.99
# 4                 7.99
# ...                ...
# 1588              7.99
# 1589             11.99
# 1590             10.99
# 1591             20.99
# 1592              3.99
#
#       Product Price ($)  \
# 0                 15.99
# 1                 12.99
# 2                  3.99
# 3                 12.99
# 4                  9.99
# ...                 ...
# 1588               8.99
# 1589              14.99
# 1590              12.99
# 1591              25.99
# 1592               7.99
#
#       Stock On Hand  \
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
#       Gross Profit ($)  \
# 0                  6.0
# 1                  3.0
# 2                  2.0
# 3                  3.0
# 4                  2.0
# ...                ...
# 1588               1.0
# 1589               3.0
# 1590               2.0
# 1591               5.0
# 1592               4.0
#
#       Year Of Store Open Date
# 0                        1992
# 1                        1992
# 2                        1992
# 3                        1992
# 4                        1992
# ...                       ...
# 1588                     2016
# 1589                     2016
# 1590                     2016
# 1591                     2016
# 1592                     2016
#
# [1593 rows x 11 columns]

# %%
a =dfMergedLeftStoredAndProductToInventory[['Store City','Store Name','Year Of Store Open Date']]
x = a.drop_duplicates()
x2 =x.sort_values(by='Year Of Store Open Date')
x2
# Out:
#             Store City  \
# 0          Guadalajara
# 35           Monterrey
# 64         Guadalajara
# 93            Saltillo
# 128             La Paz
# ...                ...
# 1401  Cuidad de Mexico
# 1459         Monterrey
# 1523          Culiacan
# 1488          Saltillo
# 1558        Guanajuato
#
#                          Store Name  \
# 0          Maven Toys Guadalajara 1
# 35           Maven Toys Monterrey 1
# 64         Maven Toys Guadalajara 2
# 93            Maven Toys Saltillo 1
# 128             Maven Toys La Paz 1
# ...                             ...
# 1401  Maven Toys Ciudad de Mexico 4
# 1459         Maven Toys Monterrey 4
# 1523          Maven Toys Culiacan 1
# 1488          Maven Toys Saltillo 2
# 1558        Maven Toys Guanajuato 3
#
#       Year Of Store Open Date
# 0                        1992
# 35                       1995
# 64                       1999
# 93                       2000
# 128                      2001
# ...                       ...
# 1401                     2015
# 1459                     2015
# 1523                     2016
# 1488                     2016
# 1558                     2016
#
# [50 rows x 3 columns]

# %%
x2.loc[(x['Store City']=='Guadalajara')]
# Out:
#        Store City  \
# 0     Guadalajara
# 64    Guadalajara
# 931   Guadalajara
# 1430  Guadalajara
#
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 64    Maven Toys Guadalajara 2
# 931   Maven Toys Guadalajara 3
# 1430  Maven Toys Guadalajara 4
#
#       Year Of Store Open Date
# 0                        1992
# 64                       1999
# 931                      2011
# 1430                     2015

# %%
x2.loc[(x['Store City']=='Saltillo')]
# Out:
#      Store City  \
# 93     Saltillo
# 1488   Saltillo
#
#                  Store Name  \
# 93    Maven Toys Saltillo 1
# 1488  Maven Toys Saltillo 2
#
#       Year Of Store Open Date
# 93                       2000
# 1488                     2016

# %%
YearOfOpenStoreData = x2.groupby(['Year Of Store Open Date'])['Year Of Store Open Date'].count().to_frame()
YearOfOpenStoreData.rename(columns = {'Year Of Store Open Date':'Quantity of Stores'}, inplace=True)
YearOfOpenStoreData.reset_index(inplace=True)
YearOfOpenStoreData
# Out:
#     Year Of Store Open Date  \
# 0                      1992
# 1                      1995
# 2                      1999
# 3                      2000
# 4                      2001
# 5                      2003
# 6                      2004
# 7                      2005
# 8                      2006
# 9                      2007
# 10                     2008
# 11                     2009
# 12                     2010
# 13                     2011
# 14                     2012
# 15                     2013
# 16                     2014
# 17                     2015
# 18                     2016
#
#     Quantity of Stores
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# 5                    2
# 6                    2
# 7                    2
# 8                    2
# 9                    4
# 10                   2
# 11                   2
# 12                   6
# 13                   3
# 14                   2
# 15                   5
# 16                   7
# 17                   3
# 18                   3

# %%
YearOfOpenStoreData
# Out:
#     Year Of Store Open Date  \
# 0                      1992
# 1                      1995
# 2                      1999
# 3                      2000
# 4                      2001
# 5                      2003
# 6                      2004
# 7                      2005
# 8                      2006
# 9                      2007
# 10                     2008
# 11                     2009
# 12                     2010
# 13                     2011
# 14                     2012
# 15                     2013
# 16                     2014
# 17                     2015
# 18                     2016
#
#     Quantity of Stores
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# 5                    2
# 6                    2
# 7                    2
# 8                    2
# 9                    4
# 10                   2
# 11                   2
# 12                   6
# 13                   3
# 14                   2
# 15                   5
# 16                   7
# 17                   3
# 18                   3

# %%
x = YearOfOpenStoreData['Year Of Store Open Date']
y = YearOfOpenStoreData['Quantity of Stores']

plt.style.use('seaborn')
plt.figure()

plt.plot(x, y, '-o')

plt.xticks(x, rotation=45)


plt.xlabel('Year of Store Open Date')
plt.ylabel('Quantity of Open Shops')
plt.title('The Quantity of Open Shops per year')

plt.show()

# %% [markdown]
# ###### Calculating the oldest and newest Store

# %%
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store Open Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#       Product Cost ($)  \
# 0                 9.99
# 1                 9.99
# 2                 1.99
# 3                 9.99
# 4                 7.99
# ...                ...
# 1588              7.99
# 1589             11.99
# 1590             10.99
# 1591             20.99
# 1592              3.99
#
#       Product Price ($)  \
# 0                 15.99
# 1                 12.99
# 2                  3.99
# 3                 12.99
# 4                  9.99
# ...                 ...
# 1588               8.99
# 1589              14.99
# 1590              12.99
# 1591              25.99
# 1592               7.99
#
#       Stock On Hand  \
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
#       Gross Profit ($)  \
# 0                  6.0
# 1                  3.0
# 2                  2.0
# 3                  3.0
# 4                  2.0
# ...                ...
# 1588               1.0
# 1589               3.0
# 1590               2.0
# 1591               5.0
# 1592               4.0
#
#       Year Of Store Open Date
# 0                        1992
# 1                        1992
# 2                        1992
# 3                        1992
# 4                        1992
# ...                       ...
# 1588                     2016
# 1589                     2016
# 1590                     2016
# 1591                     2016
# 1592                     2016
#
# [1593 rows x 11 columns]

# %%
SelectedStoreNameStoreOpenDate = dfMergedLeftStoredAndProductToInventory[['Store Name', 'Store Open Date']].drop_duplicates()
SelectedStoreNameStoreOpenDate.value_counts()
SelectedStoreNameStoreOpenDateSorted = SelectedStoreNameStoreOpenDate.sort_values(by=['Store Open Date'])
SelectedStoreNameStoreOpenDateSorted
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 35      Maven Toys Monterrey 1
# 64    Maven Toys Guadalajara 2
# 93       Maven Toys Saltillo 1
# 128        Maven Toys La Paz 1
# ...                        ...
# 1430  Maven Toys Guadalajara 4
# 1459    Maven Toys Monterrey 4
# 1488     Maven Toys Saltillo 2
# 1523     Maven Toys Culiacan 1
# 1558   Maven Toys Guanajuato 3
#
#      Store Open Date
# 0         1992-09-18
# 35        1995-04-27
# 64        1999-12-27
# 93        2000-01-01
# 128       2001-05-31
# ...              ...
# 1430      2015-10-31
# 1459      2015-11-21
# 1488      2016-03-23
# 1523      2016-05-10
# 1558      2016-05-18
#
# [50 rows x 2 columns]

# %%
SelectedStoreNameStoreOpenDateSorted.dtypes
# Out:
# Store Name                 object
# Store Open Date    datetime64[ns]
# dtype: object

# %%
SelectedStoreNameStoreOpenDateSorted['Current Date'] = pd.Timestamp.today().strftime("%Y-%m-%d")
SelectedStoreNameStoreOpenDateSorted['Current Date'] = SelectedStoreNameStoreOpenDateSorted['Current Date']\
                                                        .apply(pd.to_datetime)

# %%
SelectedStoreNameStoreOpenDateSorted.dtypes
# Out:
# Store Name                 object
# Store Open Date    datetime64[ns]
# Current Date       datetime64[ns]
# dtype: object

# %%
SelectedStoreNameStoreOpenDateSorted['Days of Open Shops'] = (SelectedStoreNameStoreOpenDateSorted["Current Date"] - SelectedStoreNameStoreOpenDateSorted["Store Open Date"])\
                                                            .dt.days
SelectedStoreNameStoreOpenDateSorted.set_index("Store Name", inplace=True)
SelectedStoreNameStoreOpenDateSorted
MaxDays = SelectedStoreNameStoreOpenDateSorted[SelectedStoreNameStoreOpenDateSorted["Days of Open Shops"] == SelectedStoreNameStoreOpenDateSorted["Days of Open Shops"].max()]
MinDays = SelectedStoreNameStoreOpenDateSorted[SelectedStoreNameStoreOpenDateSorted["Days of Open Shops"] == SelectedStoreNameStoreOpenDateSorted["Days of Open Shops"].min()]
MaxMinDaysTogether = pd.concat([MaxDays, MinDays])
MaxMinDaysTogether
# Out:
#                          Store Open Date  \
# Store Name
# Maven Toys Guadalajara 1      1992-09-18
# Maven Toys Guanajuato 3       2016-05-18
#
#                          Current Date  \
# Store Name
# Maven Toys Guadalajara 1   2022-12-26
# Maven Toys Guanajuato 3    2022-12-26
#
#                           Days of Open Shops
# Store Name
# Maven Toys Guadalajara 1               11056
# Maven Toys Guanajuato 3                 2413

# %% [markdown]
# ###### Analysis which Store  has the greatest quantity of Products and the least quantity of Products

# %%
dfMergedLeftStoredAndProductToInventory
# Out:
#                     Store Name  \
# 0     Maven Toys Guadalajara 1
# 1     Maven Toys Guadalajara 1
# 2     Maven Toys Guadalajara 1
# 3     Maven Toys Guadalajara 1
# 4     Maven Toys Guadalajara 1
# ...                        ...
# 1588   Maven Toys Guanajuato 3
# 1589   Maven Toys Guanajuato 3
# 1590   Maven Toys Guanajuato 3
# 1591   Maven Toys Guanajuato 3
# 1592   Maven Toys Guanajuato 3
#
#        Store City  \
# 0     Guadalajara
# 1     Guadalajara
# 2     Guadalajara
# 3     Guadalajara
# 4     Guadalajara
# ...           ...
# 1588   Guanajuato
# 1589   Guanajuato
# 1590   Guanajuato
# 1591   Guanajuato
# 1592   Guanajuato
#
#      Store Location  \
# 0       Residential
# 1       Residential
# 2       Residential
# 3       Residential
# 4       Residential
# ...             ...
# 1588    Residential
# 1589    Residential
# 1590    Residential
# 1591    Residential
# 1592    Residential
#
#      Store Open Date  \
# 0         1992-09-18
# 1         1992-09-18
# 2         1992-09-18
# 3         1992-09-18
# 4         1992-09-18
# ...              ...
# 1588      2016-05-18
# 1589      2016-05-18
# 1590      2016-05-18
# 1591      2016-05-18
# 1592      2016-05-18
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Splash Balls
# 1589  Supersoaker Water Gun
# 1590             Teddy Bear
# 1591              Toy Robot
# 1592          Uno Card Game
#
#        Product Category  \
# 0                  Toys
# 1                  Toys
# 2          Art & Crafts
# 3                 Games
# 4                 Games
# ...                 ...
# 1588  Sports & Outdoors
# 1589  Sports & Outdoors
# 1590               Toys
# 1591        Electronics
# 1592              Games
#
#       Product Cost ($)  \
# 0                 9.99
# 1                 9.99
# 2                 1.99
# 3                 9.99
# 4                 7.99
# ...                ...
# 1588              7.99
# 1589             11.99
# 1590             10.99
# 1591             20.99
# 1592              3.99
#
#       Product Price ($)  \
# 0                 15.99
# 1                 12.99
# 2                  3.99
# 3                 12.99
# 4                  9.99
# ...                 ...
# 1588               8.99
# 1589              14.99
# 1590              12.99
# 1591              25.99
# 1592               7.99
#
#       Stock On Hand  \
# 0                27
# 1                 0
# 2                32
# 3                 6
# 4                 0
# ...             ...
# 1588             18
# 1589              9
# 1590              1
# 1591             17
# 1592              8
#
#       Gross Profit ($)  \
# 0                  6.0
# 1                  3.0
# 2                  2.0
# 3                  3.0
# 4                  2.0
# ...                ...
# 1588               1.0
# 1589               3.0
# 1590               2.0
# 1591               5.0
# 1592               4.0
#
#       Year Of Store Open Date
# 0                        1992
# 1                        1992
# 2                        1992
# 3                        1992
# 4                        1992
# ...                       ...
# 1588                     2016
# 1589                     2016
# 1590                     2016
# 1591                     2016
# 1592                     2016
#
# [1593 rows x 11 columns]

# %%
StockOnHandByProduct = dfMergedLeftStoredAndProductToInventory.groupby(["Store Name","Product Name"])['Stock On Hand'].sum().to_frame()
StockOnHandByProduct.reset_index(inplace=True)
StockOnHandByProduct
# Out:
#                        Store Name  \
# 0     Maven Toys Aguascalientes 1
# 1     Maven Toys Aguascalientes 1
# 2     Maven Toys Aguascalientes 1
# 3     Maven Toys Aguascalientes 1
# 4     Maven Toys Aguascalientes 1
# ...                           ...
# 1588       Maven Toys Zacatecas 1
# 1589       Maven Toys Zacatecas 1
# 1590       Maven Toys Zacatecas 1
# 1591       Maven Toys Zacatecas 1
# 1592       Maven Toys Zacatecas 1
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Rubik's Cube
# 1589           Splash Balls
# 1590  Supersoaker Water Gun
# 1591             Teddy Bear
# 1592              Toy Robot
#
#       Stock On Hand
# 0                11
# 1                25
# 2                13
# 3                 1
# 4                 4
# ...             ...
# 1588             17
# 1589             10
# 1590              9
# 1591             28
# 1592             19
#
# [1593 rows x 3 columns]

# %%
MaxProduct = StockOnHandByProduct[StockOnHandByProduct["Stock On Hand"] ==StockOnHandByProduct["Stock On Hand"].max()]
MinProduct = StockOnHandByProduct[StockOnHandByProduct["Stock On Hand"] == StockOnHandByProduct["Stock On Hand"].min()]

print("The maximum quantity of Products: \n", MaxProduct.to_string(index=False))
print("The minimum quantity of Products: \n", MinProduct.to_string(index=False))
# Out:
# The maximum quantity of Products:
#                     Store Name     Product Name  Stock On Hand
# Maven Toys Ciudad de Mexico 2 Dinosaur Figures            139
# The minimum quantity of Products:
#                     Store Name          Product Name  Stock On Hand
#   Maven Toys Aguascalientes 1    Foam Disk Launcher              0
#   Maven Toys Aguascalientes 1     Hot Wheels 5-Pack              0
#   Maven Toys Aguascalientes 1    Mini Ping Pong Set              0
#   Maven Toys Aguascalientes 1              Playfoam              0
#        Maven Toys Chihuahua 2    Foam Disk Launcher              0
#     Maven Toys Chilpancingo 1     Hot Wheels 5-Pack              0
#  Maven Toys Ciudad Victoria 1          Splash Balls              0
# Maven Toys Ciudad de Mexico 3        Mr. Potatohead              0
# Maven Toys Ciudad de Mexico 3 Supersoaker Water Gun              0
# Maven Toys Ciudad de Mexico 4              Dino Egg              0
# Maven Toys Ciudad de Mexico 4              Playfoam              0
#       Maven Toys Cuernavaca 1    Mini Ping Pong Set              0
#         Maven Toys Culiacan 1        Animal Figures              0
#         Maven Toys Culiacan 1     Hot Wheels 5-Pack              0
#      Maven Toys Guadalajara 1        Animal Figures              0
#      Maven Toys Guadalajara 1      Classic Dominoes              0
#      Maven Toys Guadalajara 1             Toy Robot              0
#      Maven Toys Guadalajara 2     Hot Wheels 5-Pack              0
#      Maven Toys Guadalajara 2            Plush Pony              0
#       Maven Toys Guanajuato 1     Hot Wheels 5-Pack              0
#       Maven Toys Guanajuato 1    Mini Ping Pong Set              0
#       Maven Toys Guanajuato 1            Plush Pony              0
#       Maven Toys Guanajuato 2       Barrel O' Slime              0
#       Maven Toys Guanajuato 2     Hot Wheels 5-Pack              0
#       Maven Toys Guanajuato 2              Playfoam              0
#       Maven Toys Guanajuato 3    Foam Disk Launcher              0
#       Maven Toys Guanajuato 3              Playfoam              0
#       Maven Toys Hermosillo 1    Mini Ping Pong Set              0
#       Maven Toys Hermosillo 2      Chutes & Ladders              0
#       Maven Toys Hermosillo 2         Etch A Sketch              0
#       Maven Toys Hermosillo 2              Playfoam              0
#       Maven Toys Hermosillo 2            Plush Pony              0
#       Maven Toys Hermosillo 3                 Jenga              0
#       Maven Toys Hermosillo 3              Playfoam              0
#           Maven Toys La Paz 1         Etch A Sketch              0
#           Maven Toys La Paz 1    Foam Disk Launcher              0
#           Maven Toys La Paz 1     Hot Wheels 5-Pack              0
#           Maven Toys La Paz 1    Mini Ping Pong Set              0
#           Maven Toys La Paz 1              Playfoam              0
#           Maven Toys Merida 1              Playfoam              0
#         Maven Toys Mexicali 1         Action Figure              0
#         Maven Toys Mexicali 2         Action Figure              0
#         Maven Toys Mexicali 2              Dino Egg              0
#         Maven Toys Mexicali 2         Etch A Sketch              0
#         Maven Toys Mexicali 2    Foam Disk Launcher              0
#         Maven Toys Mexicali 2              Playfoam              0
#        Maven Toys Monterrey 1         Action Figure              0
#        Maven Toys Monterrey 1              Dino Egg              0
#        Maven Toys Monterrey 1         Etch A Sketch              0
#        Maven Toys Monterrey 2              Dino Egg              0
#        Maven Toys Monterrey 2              Playfoam              0
#        Maven Toys Monterrey 3      Gamer Headphones              0
#        Maven Toys Monterrey 3     Hot Wheels 5-Pack              0
#          Maven Toys Morelia 1      Chutes & Ladders              0
#           Maven Toys Oaxaca 1         Etch A Sketch              0
#          Maven Toys Pachuca 1              Dino Egg              0
#          Maven Toys Pachuca 1      Gamer Headphones              0
#          Maven Toys Pachuca 1         Glass Marbles              0
#          Maven Toys Pachuca 1     Hot Wheels 5-Pack              0
#           Maven Toys Puebla 1         Etch A Sketch              0
#           Maven Toys Puebla 1     Hot Wheels 5-Pack              0
#           Maven Toys Puebla 1            Teddy Bear              0
#           Maven Toys Puebla 2        Animal Figures              0
#           Maven Toys Puebla 2     Hot Wheels 5-Pack              0
#           Maven Toys Puebla 3         Action Figure              0
#           Maven Toys Puebla 3         Etch A Sketch              0
#           Maven Toys Puebla 3            Teddy Bear              0
#         Maven Toys Saltillo 1             Toy Robot              0
#         Maven Toys Saltillo 2            Teddy Bear              0
#  Maven Toys San Luis Potosi 1              Playfoam              0
#           Maven Toys Toluca 2              Playfoam              0
# Maven Toys Tuxtla Gutierrez 1    Foam Disk Launcher              0
#     Maven Toys Villahermosa 1              Dino Egg              0
#           Maven Toys Xalapa 2         Action Figure              0
#           Maven Toys Xalapa 2     Hot Wheels 5-Pack              0
#           Maven Toys Xalapa 2              Playfoam              0
#        Maven Toys Zacatecas 1    Mini Ping Pong Set              0

# %%
StockOnHandByProduct
# Out:
#                        Store Name  \
# 0     Maven Toys Aguascalientes 1
# 1     Maven Toys Aguascalientes 1
# 2     Maven Toys Aguascalientes 1
# 3     Maven Toys Aguascalientes 1
# 4     Maven Toys Aguascalientes 1
# ...                           ...
# 1588       Maven Toys Zacatecas 1
# 1589       Maven Toys Zacatecas 1
# 1590       Maven Toys Zacatecas 1
# 1591       Maven Toys Zacatecas 1
# 1592       Maven Toys Zacatecas 1
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1588           Rubik's Cube
# 1589           Splash Balls
# 1590  Supersoaker Water Gun
# 1591             Teddy Bear
# 1592              Toy Robot
#
#       Stock On Hand
# 0                11
# 1                25
# 2                13
# 3                 1
# 4                 4
# ...             ...
# 1588             17
# 1589             10
# 1590              9
# 1591             28
# 1592             19
#
# [1593 rows x 3 columns]

# %%
GroupedStockOnHandByProduct = StockOnHandByProduct.groupby(['Store Name','Product Name'])['Stock On Hand'].agg('sum').to_frame()
GroupedStockOnHandByProduct
# Out:
#                                                    Stock On Hand
# Store Name                  Product Name
# Maven Toys Aguascalientes 1 Action Figure                     11
#                             Animal Figures                    25
#                             Barrel O' Slime                   13
#                             Chutes & Ladders                   1
#                             Classic Dominoes                   4
# ...                                                          ...
# Maven Toys Zacatecas 1      Rubik's Cube                      17
#                             Splash Balls                      10
#                             Supersoaker Water Gun              9
#                             Teddy Bear                        28
#                             Toy Robot                         19
#
# [1593 rows x 1 columns]

# %%
MaxStockOnHandAguascalientes1 = GroupedStockOnHandByProduct.loc['Maven Toys Aguascalientes 1'].reset_index()
MaxStockOnHandAguascalientes1[MaxStockOnHandAguascalientes1["Stock On Hand"] == MaxStockOnHandAguascalientes1["Stock On Hand"].max()]
# Out:
#    Product Name  \
# 18   Magic Sand
#
#     Stock On Hand
# 18             67

# %%
MaxStockOnHandZacatecas1=GroupedStockOnHandByProduct.loc["Maven Toys Zacatecas 1"].reset_index()
MaxStockOnHandZacatecas1[MaxStockOnHandZacatecas1["Stock On Hand"] == MaxStockOnHandZacatecas1["Stock On Hand"].max()]
# Out:
#    Product Name  \
# 19  PlayDoh Can
#
#     Stock On Hand
# 19             92

# %%
GroupedStockOnHandByProduct
MaxQuantityOfProductByStore = GroupedStockOnHandByProduct[GroupedStockOnHandByProduct['Stock On Hand'] == GroupedStockOnHandByProduct.groupby(['Store Name'])['Stock On Hand'].transform('max')]
MaxQuantityOfProductByStore.reset_index(inplace=True)
MaxQuantityOfProductByStore
# Out:
#                        Store Name  \
# 0     Maven Toys Aguascalientes 1
# 1           Maven Toys Campeche 1
# 2           Maven Toys Campeche 2
# 3           Maven Toys Chetumal 1
# 4          Maven Toys Chihuahua 1
# ..                            ...
# 47  Maven Toys Tuxtla Gutierrez 1
# 48      Maven Toys Villahermosa 1
# 49            Maven Toys Xalapa 1
# 50            Maven Toys Xalapa 2
# 51         Maven Toys Zacatecas 1
#
#      Product Name  \
# 0      Magic Sand
# 1   Deck Of Cards
# 2      Magic Sand
# 3   Deck Of Cards
# 4        Playfoam
# ..            ...
# 47     Magic Sand
# 48    PlayDoh Can
# 49    PlayDoh Can
# 50  Deck Of Cards
# 51    PlayDoh Can
#
#     Stock On Hand
# 0              67
# 1              73
# 2              90
# 3              61
# 4              48
# ..            ...
# 47             63
# 48            131
# 49             47
# 50             90
# 51             92
#
# [52 rows x 3 columns]

# %%
MinStockOnHandMavenToysChetumal1 = GroupedStockOnHandByProduct.loc['Maven Toys Chetumal 1'].reset_index()
MinStockOnHandMavenToysChetumal1[MinStockOnHandMavenToysChetumal1["Stock On Hand"] == MinStockOnHandMavenToysChetumal1["Stock On Hand"].min()]
# Out:
#    Product Name  \
# 21     Monopoly
#
#     Stock On Hand
# 21              4

# %%
MinStockOnHandMavenToysLaPaz1 = GroupedStockOnHandByProduct.loc['Maven Toys La Paz 1'].reset_index()
MinStockOnHandMavenToysLaPaz1[MinStockOnHandMavenToysLaPaz1["Stock On Hand"] == MinStockOnHandMavenToysLaPaz1["Stock On Hand"].min()]
# Out:
#           Product Name  \
# 8        Etch A Sketch
# 9   Foam Disk Launcher
# 12   Hot Wheels 5-Pack
# 16  Mini Ping Pong Set
# 22            Playfoam
#
#     Stock On Hand
# 8               0
# 9               0
# 12              0
# 16              0
# 22              0

# %%
GroupedStockOnHandByProduct
MinQuantityOfProductByStore = GroupedStockOnHandByProduct[GroupedStockOnHandByProduct['Stock On Hand'] 
                                                          == GroupedStockOnHandByProduct.groupby(['Store Name'])['Stock On Hand'].transform('min')]
MinQuantityOfProductByStore.reset_index(inplace=True)
MinQuantityOfProductByStoreWithoutDuplicates = MinQuantityOfProductByStore.drop_duplicates(subset=['Store Name'], keep="last")
MinQuantityOfProductByStoreWithoutDuplicates
# Out:
#                        Store Name  \
# 3     Maven Toys Aguascalientes 1
# 4           Maven Toys Campeche 1
# 8           Maven Toys Campeche 2
# 9           Maven Toys Chetumal 1
# 10         Maven Toys Chihuahua 1
# ..                            ...
# 88  Maven Toys Tuxtla Gutierrez 1
# 89      Maven Toys Villahermosa 1
# 90            Maven Toys Xalapa 1
# 93            Maven Toys Xalapa 2
# 94         Maven Toys Zacatecas 1
#
#             Product Name  \
# 3               Playfoam
# 4                  Jenga
# 8             Teddy Bear
# 9               Monopoly
# 10  Mini Basketball Hoop
# ..                   ...
# 88    Foam Disk Launcher
# 89              Dino Egg
# 90              Playfoam
# 93              Playfoam
# 94    Mini Ping Pong Set
#
#     Stock On Hand
# 3               0
# 4               1
# 8               2
# 9               4
# 10              2
# ..            ...
# 88              0
# 89              0
# 90              1
# 93              0
# 94              0
#
# [50 rows x 3 columns]

# %% [markdown]
# ##### Combining two datasets into one with the maximum and minimum quantity of Products in each stock

# %%
MergeMaxAndMinQuantity = pd.merge(MaxQuantityOfProductByStore,MinQuantityOfProductByStoreWithoutDuplicates, on='Store Name'
                                ,how="outer", suffixes=('_left','_right'))

# %%
MergeMaxAndMinQuantity.rename(columns = {'Product Name_left' : 'The Max Quantity Of Product Name',
                                        'Stock On Hand_left' : 'Max Quantity',
                                        'Product Name_right' : 'The Min Quantity Of Product Name',
                                        'Stock On Hand_right' : 'Min Quantity'},inplace=True)

MergeMaxAndMinQuantity
# Out:
#                        Store Name  \
# 0     Maven Toys Aguascalientes 1
# 1           Maven Toys Campeche 1
# 2           Maven Toys Campeche 2
# 3           Maven Toys Chetumal 1
# 4          Maven Toys Chihuahua 1
# ..                            ...
# 47  Maven Toys Tuxtla Gutierrez 1
# 48      Maven Toys Villahermosa 1
# 49            Maven Toys Xalapa 1
# 50            Maven Toys Xalapa 2
# 51         Maven Toys Zacatecas 1
#
#    The Max Quantity Of Product Name  \
# 0                        Magic Sand
# 1                     Deck Of Cards
# 2                        Magic Sand
# 3                     Deck Of Cards
# 4                          Playfoam
# ..                              ...
# 47                       Magic Sand
# 48                      PlayDoh Can
# 49                      PlayDoh Can
# 50                    Deck Of Cards
# 51                      PlayDoh Can
#
#     Max Quantity  \
# 0             67
# 1             73
# 2             90
# 3             61
# 4             48
# ..           ...
# 47            63
# 48           131
# 49            47
# 50            90
# 51            92
#
#    The Min Quantity Of Product Name  \
# 0                          Playfoam
# 1                             Jenga
# 2                        Teddy Bear
# 3                          Monopoly
# 4              Mini Basketball Hoop
# ..                              ...
# 47               Foam Disk Launcher
# 48                         Dino Egg
# 49                         Playfoam
# 50                         Playfoam
# 51               Mini Ping Pong Set
#
#     Min Quantity
# 0              0
# 1              1
# 2              2
# 3              4
# 4              2
# ..           ...
# 47             0
# 48             0
# 49             1
# 50             0
# 51             0
#
# [52 rows x 5 columns]

# %% [markdown]
# ## Analysis of Sales

# %% [markdown]
# ### Combining dataframes

# %%
dfSales = pd.read_csv("D:\My commercial projects\Python\Mexico Toy Sales\sales.csv")
dfProducts = pd.read_csv("D:\My commercial projects\Python\Mexico Toy Sales\products.csv")
dfInventory = pd.read_csv("D:\My commercial projects\Python\Mexico Toy Sales\inventory.csv")
dfStores = pd.read_csv("D:\My commercial projects\Python\Mexico Toy Sales\stores.csv")
dfSales, dfProducts, dfInventory, dfStores
# Out:
# (        Sale_ID  \
#  0             1
#  1             2
#  2             3
#  3             4
#  4             5
#  ...         ...
#  829257   829258
#  829258   829259
#  829259   829260
#  829260   829261
#  829261   829262
#
#                Date  \
#  0       2017-01-01
#  1       2017-01-01
#  2       2017-01-01
#  3       2017-01-01
#  4       2017-01-01
#  ...            ...
#  829257  2018-09-30
#  829258  2018-09-30
#  829259  2018-09-30
#  829260  2018-09-30
#  829261  2018-09-30
#
#          Store_ID  \
#  0             24
#  1             28
#  2              6
#  3             48
#  4             44
#  ...          ...
#  829257        24
#  829258        16
#  829259        22
#  829260        13
#  829261        32
#
#          Product_ID  \
#  0                4
#  1                1
#  2                8
#  3                7
#  4               18
#  ...            ...
#  829257          19
#  829258          35
#  829259          19
#  829260           2
#  829261           6
#
#          Units
#  0           1
#  1           1
#  2           1
#  3           1
#  4           1
#  ...       ...
#  829257      1
#  829258      1
#  829259      1
#  829260      2
#  829261      1
#
#  [829262 rows x 5 columns],
#      Product_ID  \
#  0            1
#  1            2
#  2            3
#  3            4
#  4            5
#  ..         ...
#  30          31
#  31          32
#  32          33
#  33          34
#  34          35
#
#               Product_Name  \
#  0           Action Figure
#  1          Animal Figures
#  2         Barrel O' Slime
#  3        Chutes & Ladders
#  4        Classic Dominoes
#  ..                    ...
#  30           Splash Balls
#  31  Supersoaker Water Gun
#  32             Teddy Bear
#  33              Toy Robot
#  34          Uno Card Game
#
#       Product_Category  \
#  0                Toys
#  1                Toys
#  2        Art & Crafts
#  3               Games
#  4               Games
#  ..                ...
#  30  Sports & Outdoors
#  31  Sports & Outdoors
#  32               Toys
#  33        Electronics
#  34              Games
#
#     Product_Cost  \
#  0        $9.99
#  1        $9.99
#  2        $1.99
#  3        $9.99
#  4        $7.99
#  ..          ...
#  30       $7.99
#  31      $11.99
#  32      $10.99
#  33      $20.99
#  34       $3.99
#
#     Product_Price
#  0        $15.99
#  1        $12.99
#  2         $3.99
#  3        $12.99
#  4         $9.99
#  ..           ...
#  30        $8.99
#  31       $14.99
#  32       $12.99
#  33       $25.99
#  34        $7.99
#
#  [35 rows x 5 columns],
#        Store_ID  \
#  0            1
#  1            1
#  2            1
#  3            1
#  4            1
#  ...        ...
#  1588        50
#  1589        50
#  1590        50
#  1591        50
#  1592        50
#
#        Product_ID  \
#  0              1
#  1              2
#  2              3
#  3              4
#  4              5
#  ...          ...
#  1588          31
#  1589          32
#  1590          33
#  1591          34
#  1592          35
#
#        Stock_On_Hand
#  0                27
#  1                 0
#  2                32
#  3                 6
#  4                 0
#  ...             ...
#  1588             18
#  1589              9
#  1590              1
#  1591             17
#  1592              8
#
#  [1593 rows x 3 columns],
#      Store_ID  \
#  0          1
#  1          2
#  2          3
#  3          4
#  4          5
#  ..       ...
#  45        46
#  46        47
#  47        48
#  48        49
#  49        50
#
#                    Store_Name  \
#  0   Maven Toys Guadalajara 1
#  1     Maven Toys Monterrey 1
#  2   Maven Toys Guadalajara 2
#  3      Maven Toys Saltillo 1
#  4        Maven Toys La Paz 1
#  ..                       ...
#  45  Maven Toys Guadalajara 4
#  46    Maven Toys Monterrey 4
#  47     Maven Toys Saltillo 2
#  48     Maven Toys Culiacan 1
#  49   Maven Toys Guanajuato 3
#
#       Store_City  \
#  0   Guadalajara
#  1     Monterrey
#  2   Guadalajara
#  3      Saltillo
#  4        La Paz
#  ..          ...
#  45  Guadalajara
#  46    Monterrey
#  47     Saltillo
#  48     Culiacan
#  49   Guanajuato
#
#     Store_Location  \
#  0     Residential
#  1     Residential
#  2      Commercial
#  3        Downtown
#  4        Downtown
#  ..            ...
#  45       Downtown
#  46     Commercial
#  47     Commercial
#  48       Downtown
#  49    Residential
#
#     Store_Open_Date
#  0       1992-09-18
#  1       1995-04-27
#  2       1999-12-27
#  3       2000-01-01
#  4       2001-05-31
#  ..             ...
#  45      2015-10-31
#  46      2015-11-21
#  47      2016-03-23
#  48      2016-05-10
#  49      2016-05-18
#
#  [50 rows x 5 columns])

# %%
dfSalesProductsInventoryMerged = pd.merge(pd.merge(pd.merge(dfSales,dfProducts, on='Product_ID', how='inner')\
                                          ,dfInventory,on='Store_ID',how='inner')\
                                          ,dfStores, on='Store_ID', how='inner')

# %%
dfSalesProductsInventoryMerged
# Out:
#           Sale_ID  \
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 26405711   821027
# 26405712   821027
# 26405713   821027
# 26405714   821027
# 26405715   821027
#
#                 Date  \
# 0         2017-01-01
# 1         2017-01-01
# 2         2017-01-01
# 3         2017-01-01
# 4         2017-01-01
# ...              ...
# 26405711  2018-09-25
# 26405712  2018-09-25
# 26405713  2018-09-25
# 26405714  2018-09-25
# 26405715  2018-09-25
#
#           Store_ID  \
# 0               24
# 1               24
# 2               24
# 3               24
# 4               24
# ...            ...
# 26405711        13
# 26405712        13
# 26405713        13
# 26405714        13
# 26405715        13
#
#           Product_ID_x  \
# 0                    4
# 1                    4
# 2                    4
# 3                    4
# 4                    4
# ...                ...
# 26405711            28
# 26405712            28
# 26405713            28
# 26405714            28
# 26405715            28
#
#           Units  \
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 26405711      1
# 26405712      1
# 26405713      1
# 26405714      1
# 26405715      1
#
#               Product_Name  \
# 0         Chutes & Ladders
# 1         Chutes & Ladders
# 2         Chutes & Ladders
# 3         Chutes & Ladders
# 4         Chutes & Ladders
# ...                    ...
# 26405711          Playfoam
# 26405712          Playfoam
# 26405713          Playfoam
# 26405714          Playfoam
# 26405715          Playfoam
#
#          Product_Category  \
# 0                   Games
# 1                   Games
# 2                   Games
# 3                   Games
# 4                   Games
# ...                   ...
# 26405711     Art & Crafts
# 26405712     Art & Crafts
# 26405713     Art & Crafts
# 26405714     Art & Crafts
# 26405715     Art & Crafts
#
#          Product_Cost  \
# 0              $9.99
# 1              $9.99
# 2              $9.99
# 3              $9.99
# 4              $9.99
# ...               ...
# 26405711       $3.99
# 26405712       $3.99
# 26405713       $3.99
# 26405714       $3.99
# 26405715       $3.99
#
#          Product_Price  \
# 0              $12.99
# 1              $12.99
# 2              $12.99
# 3              $12.99
# 4              $12.99
# ...                ...
# 26405711       $10.99
# 26405712       $10.99
# 26405713       $10.99
# 26405714       $10.99
# 26405715       $10.99
#
#           Product_ID_y  \
# 0                    1
# 1                    2
# 2                    3
# 3                    4
# 4                    5
# ...                ...
# 26405711            30
# 26405712            31
# 26405713            32
# 26405714            33
# 26405715            34
#
#           Stock_On_Hand  \
# 0                    11
# 1                    25
# 2                    13
# 3                     1
# 4                     4
# ...                 ...
# 26405711             17
# 26405712             24
# 26405713              7
# 26405714              3
# 26405715              3
#
#                            Store_Name  \
# 0         Maven Toys Aguascalientes 1
# 1         Maven Toys Aguascalientes 1
# 2         Maven Toys Aguascalientes 1
# 3         Maven Toys Aguascalientes 1
# 4         Maven Toys Aguascalientes 1
# ...                               ...
# 26405711        Maven Toys Mexicali 2
# 26405712        Maven Toys Mexicali 2
# 26405713        Maven Toys Mexicali 2
# 26405714        Maven Toys Mexicali 2
# 26405715        Maven Toys Mexicali 2
#
#               Store_City  \
# 0         Aguascalientes
# 1         Aguascalientes
# 2         Aguascalientes
# 3         Aguascalientes
# 4         Aguascalientes
# ...                  ...
# 26405711        Mexicali
# 26405712        Mexicali
# 26405713        Mexicali
# 26405714        Mexicali
# 26405715        Mexicali
#
#          Store_Location  \
# 0              Downtown
# 1              Downtown
# 2              Downtown
# 3              Downtown
# 4              Downtown
# ...                 ...
# 26405711       Downtown
# 26405712       Downtown
# 26405713       Downtown
# 26405714       Downtown
# 26405715       Downtown
#
#          Store_Open_Date
# 0             2010-07-31
# 1             2010-07-31
# 2             2010-07-31
# 3             2010-07-31
# 4             2010-07-31
# ...                  ...
# 26405711      2006-08-30
# 26405712      2006-08-30
# 26405713      2006-08-30
# 26405714      2006-08-30
# 26405715      2006-08-30
#
# [26405716 rows x 15 columns]

# %%
dfSalesProductsInventoryMerged.drop(['Store_ID','Product_ID_x','Units','Product_ID_y','Store_Name','Store_Location'], axis=1, inplace=True)

# %% [markdown]
# ### EDA: Preparing Dataframe

# %%
dfSalesProductsInventoryMerged
# Out:
#           Sale_ID  \
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 26405711   821027
# 26405712   821027
# 26405713   821027
# 26405714   821027
# 26405715   821027
#
#                 Date  \
# 0         2017-01-01
# 1         2017-01-01
# 2         2017-01-01
# 3         2017-01-01
# 4         2017-01-01
# ...              ...
# 26405711  2018-09-25
# 26405712  2018-09-25
# 26405713  2018-09-25
# 26405714  2018-09-25
# 26405715  2018-09-25
#
#               Product_Name  \
# 0         Chutes & Ladders
# 1         Chutes & Ladders
# 2         Chutes & Ladders
# 3         Chutes & Ladders
# 4         Chutes & Ladders
# ...                    ...
# 26405711          Playfoam
# 26405712          Playfoam
# 26405713          Playfoam
# 26405714          Playfoam
# 26405715          Playfoam
#
#          Product_Category  \
# 0                   Games
# 1                   Games
# 2                   Games
# 3                   Games
# 4                   Games
# ...                   ...
# 26405711     Art & Crafts
# 26405712     Art & Crafts
# 26405713     Art & Crafts
# 26405714     Art & Crafts
# 26405715     Art & Crafts
#
#          Product_Cost  \
# 0              $9.99
# 1              $9.99
# 2              $9.99
# 3              $9.99
# 4              $9.99
# ...               ...
# 26405711       $3.99
# 26405712       $3.99
# 26405713       $3.99
# 26405714       $3.99
# 26405715       $3.99
#
#          Product_Price  \
# 0              $12.99
# 1              $12.99
# 2              $12.99
# 3              $12.99
# 4              $12.99
# ...                ...
# 26405711       $10.99
# 26405712       $10.99
# 26405713       $10.99
# 26405714       $10.99
# 26405715       $10.99
#
#           Stock_On_Hand  \
# 0                    11
# 1                    25
# 2                    13
# 3                     1
# 4                     4
# ...                 ...
# 26405711             17
# 26405712             24
# 26405713              7
# 26405714              3
# 26405715              3
#
#               Store_City  \
# 0         Aguascalientes
# 1         Aguascalientes
# 2         Aguascalientes
# 3         Aguascalientes
# 4         Aguascalientes
# ...                  ...
# 26405711        Mexicali
# 26405712        Mexicali
# 26405713        Mexicali
# 26405714        Mexicali
# 26405715        Mexicali
#
#          Store_Open_Date
# 0             2010-07-31
# 1             2010-07-31
# 2             2010-07-31
# 3             2010-07-31
# 4             2010-07-31
# ...                  ...
# 26405711      2006-08-30
# 26405712      2006-08-30
# 26405713      2006-08-30
# 26405714      2006-08-30
# 26405715      2006-08-30
#
# [26405716 rows x 9 columns]

# %%
dfSalesProductsInventoryMerged['Product_Cost'] = dfSalesProductsInventoryMerged['Product_Cost']\
                                                    .apply(lambda x:x.replace('$','')).astype('float')
dfSalesProductsInventoryMerged['Product_Price'] = dfSalesProductsInventoryMerged['Product_Price']\
                                                    .apply(lambda x:x.replace('$','')).astype('float')

# %%
dfSalesProductsInventoryMerged['Gross Profit ($)'] = dfSalesProductsInventoryMerged['Product_Price'] - dfSalesProductsInventoryMerged['Product_Cost']

# %%
dfSalesProductsInventoryMerged
# Out:
#           Sale_ID  \
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 26405711   821027
# 26405712   821027
# 26405713   821027
# 26405714   821027
# 26405715   821027
#
#                 Date  \
# 0         2017-01-01
# 1         2017-01-01
# 2         2017-01-01
# 3         2017-01-01
# 4         2017-01-01
# ...              ...
# 26405711  2018-09-25
# 26405712  2018-09-25
# 26405713  2018-09-25
# 26405714  2018-09-25
# 26405715  2018-09-25
#
#               Product_Name  \
# 0         Chutes & Ladders
# 1         Chutes & Ladders
# 2         Chutes & Ladders
# 3         Chutes & Ladders
# 4         Chutes & Ladders
# ...                    ...
# 26405711          Playfoam
# 26405712          Playfoam
# 26405713          Playfoam
# 26405714          Playfoam
# 26405715          Playfoam
#
#          Product_Category  \
# 0                   Games
# 1                   Games
# 2                   Games
# 3                   Games
# 4                   Games
# ...                   ...
# 26405711     Art & Crafts
# 26405712     Art & Crafts
# 26405713     Art & Crafts
# 26405714     Art & Crafts
# 26405715     Art & Crafts
#
#           Product_Cost  \
# 0                 9.99
# 1                 9.99
# 2                 9.99
# 3                 9.99
# 4                 9.99
# ...                ...
# 26405711          3.99
# 26405712          3.99
# 26405713          3.99
# 26405714          3.99
# 26405715          3.99
#
#           Product_Price  \
# 0                 12.99
# 1                 12.99
# 2                 12.99
# 3                 12.99
# 4                 12.99
# ...                 ...
# 26405711          10.99
# 26405712          10.99
# 26405713          10.99
# 26405714          10.99
# 26405715          10.99
#
#           Stock_On_Hand  \
# 0                    11
# 1                    25
# 2                    13
# 3                     1
# 4                     4
# ...                 ...
# 26405711             17
# 26405712             24
# 26405713              7
# 26405714              3
# 26405715              3
#
#               Store_City  \
# 0         Aguascalientes
# 1         Aguascalientes
# 2         Aguascalientes
# 3         Aguascalientes
# 4         Aguascalientes
# ...                  ...
# 26405711        Mexicali
# 26405712        Mexicali
# 26405713        Mexicali
# 26405714        Mexicali
# 26405715        Mexicali
#
#          Store_Open_Date  \
# 0             2010-07-31
# 1             2010-07-31
# 2             2010-07-31
# 3             2010-07-31
# 4             2010-07-31
# ...                  ...
# 26405711      2006-08-30
# 26405712      2006-08-30
# 26405713      2006-08-30
# 26405714      2006-08-30
# 26405715      2006-08-30
#
#           Gross Profit ($)
# 0                      3.0
# 1                      3.0
# 2                      3.0
# 3                      3.0
# 4                      3.0
# ...                    ...
# 26405711               7.0
# 26405712               7.0
# 26405713               7.0
# 26405714               7.0
# 26405715               7.0
#
# [26405716 rows x 10 columns]

# %% [markdown]
# #### Removing duplicated ones

# %%
duplicates = dfSalesProductsInventoryMerged.duplicated()
duplicates.sum()
# Out:
# 8183638

# %%
dfSalesProductsInventoryMerged.drop_duplicates(inplace=True)

# %%
dfSalesProductsInventoryMerged
# Out:
#           Sale_ID  \
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 26405705   821027
# 26405706   821027
# 26405708   821027
# 26405711   821027
# 26405713   821027
#
#                 Date  \
# 0         2017-01-01
# 1         2017-01-01
# 2         2017-01-01
# 3         2017-01-01
# 4         2017-01-01
# ...              ...
# 26405705  2018-09-25
# 26405706  2018-09-25
# 26405708  2018-09-25
# 26405711  2018-09-25
# 26405713  2018-09-25
#
#               Product_Name  \
# 0         Chutes & Ladders
# 1         Chutes & Ladders
# 2         Chutes & Ladders
# 3         Chutes & Ladders
# 4         Chutes & Ladders
# ...                    ...
# 26405705          Playfoam
# 26405706          Playfoam
# 26405708          Playfoam
# 26405711          Playfoam
# 26405713          Playfoam
#
#          Product_Category  \
# 0                   Games
# 1                   Games
# 2                   Games
# 3                   Games
# 4                   Games
# ...                   ...
# 26405705     Art & Crafts
# 26405706     Art & Crafts
# 26405708     Art & Crafts
# 26405711     Art & Crafts
# 26405713     Art & Crafts
#
#           Product_Cost  \
# 0                 9.99
# 1                 9.99
# 2                 9.99
# 3                 9.99
# 4                 9.99
# ...                ...
# 26405705          3.99
# 26405706          3.99
# 26405708          3.99
# 26405711          3.99
# 26405713          3.99
#
#           Product_Price  \
# 0                 12.99
# 1                 12.99
# 2                 12.99
# 3                 12.99
# 4                 12.99
# ...                 ...
# 26405705          10.99
# 26405706          10.99
# 26405708          10.99
# 26405711          10.99
# 26405713          10.99
#
#           Stock_On_Hand  \
# 0                    11
# 1                    25
# 2                    13
# 3                     1
# 4                     4
# ...                 ...
# 26405705             24
# 26405706             37
# 26405708             56
# 26405711             17
# 26405713              7
#
#               Store_City  \
# 0         Aguascalientes
# 1         Aguascalientes
# 2         Aguascalientes
# 3         Aguascalientes
# 4         Aguascalientes
# ...                  ...
# 26405705        Mexicali
# 26405706        Mexicali
# 26405708        Mexicali
# 26405711        Mexicali
# 26405713        Mexicali
#
#          Store_Open_Date  \
# 0             2010-07-31
# 1             2010-07-31
# 2             2010-07-31
# 3             2010-07-31
# 4             2010-07-31
# ...                  ...
# 26405705      2006-08-30
# 26405706      2006-08-30
# 26405708      2006-08-30
# 26405711      2006-08-30
# 26405713      2006-08-30
#
#           Gross Profit ($)
# 0                      3.0
# 1                      3.0
# 2                      3.0
# 3                      3.0
# 4                      3.0
# ...                    ...
# 26405705               7.0
# 26405706               7.0
# 26405708               7.0
# 26405711               7.0
# 26405713               7.0
#
# [18222078 rows x 10 columns]

# %% [markdown]
# #### Removing NaN values

# %%
NaN_Values = dfSalesProductsInventoryMerged[dfSalesProductsInventoryMerged.isnull().any(axis=1)]
NaN_Values
# Out:
# Empty DataFrame
# Columns: [Sale_ID, Date, Product_Name, Product_Category, Product_Cost, Product_Price, Stock_On_Hand, Store_City, Store_Open_Date, Gross Profit ($)]
# Index: []

# %%
dfSalesProductsInventoryMerged.dropna(inplace=True)

# %%
dfSalesProductsInventoryMerged
# Out:
#           Sale_ID  \
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 26405705   821027
# 26405706   821027
# 26405708   821027
# 26405711   821027
# 26405713   821027
#
#                 Date  \
# 0         2017-01-01
# 1         2017-01-01
# 2         2017-01-01
# 3         2017-01-01
# 4         2017-01-01
# ...              ...
# 26405705  2018-09-25
# 26405706  2018-09-25
# 26405708  2018-09-25
# 26405711  2018-09-25
# 26405713  2018-09-25
#
#               Product_Name  \
# 0         Chutes & Ladders
# 1         Chutes & Ladders
# 2         Chutes & Ladders
# 3         Chutes & Ladders
# 4         Chutes & Ladders
# ...                    ...
# 26405705          Playfoam
# 26405706          Playfoam
# 26405708          Playfoam
# 26405711          Playfoam
# 26405713          Playfoam
#
#          Product_Category  \
# 0                   Games
# 1                   Games
# 2                   Games
# 3                   Games
# 4                   Games
# ...                   ...
# 26405705     Art & Crafts
# 26405706     Art & Crafts
# 26405708     Art & Crafts
# 26405711     Art & Crafts
# 26405713     Art & Crafts
#
#           Product_Cost  \
# 0                 9.99
# 1                 9.99
# 2                 9.99
# 3                 9.99
# 4                 9.99
# ...                ...
# 26405705          3.99
# 26405706          3.99
# 26405708          3.99
# 26405711          3.99
# 26405713          3.99
#
#           Product_Price  \
# 0                 12.99
# 1                 12.99
# 2                 12.99
# 3                 12.99
# 4                 12.99
# ...                 ...
# 26405705          10.99
# 26405706          10.99
# 26405708          10.99
# 26405711          10.99
# 26405713          10.99
#
#           Stock_On_Hand  \
# 0                    11
# 1                    25
# 2                    13
# 3                     1
# 4                     4
# ...                 ...
# 26405705             24
# 26405706             37
# 26405708             56
# 26405711             17
# 26405713              7
#
#               Store_City  \
# 0         Aguascalientes
# 1         Aguascalientes
# 2         Aguascalientes
# 3         Aguascalientes
# 4         Aguascalientes
# ...                  ...
# 26405705        Mexicali
# 26405706        Mexicali
# 26405708        Mexicali
# 26405711        Mexicali
# 26405713        Mexicali
#
#          Store_Open_Date  \
# 0             2010-07-31
# 1             2010-07-31
# 2             2010-07-31
# 3             2010-07-31
# 4             2010-07-31
# ...                  ...
# 26405705      2006-08-30
# 26405706      2006-08-30
# 26405708      2006-08-30
# 26405711      2006-08-30
# 26405713      2006-08-30
#
#           Gross Profit ($)
# 0                      3.0
# 1                      3.0
# 2                      3.0
# 3                      3.0
# 4                      3.0
# ...                    ...
# 26405705               7.0
# 26405706               7.0
# 26405708               7.0
# 26405711               7.0
# 26405713               7.0
#
# [18222078 rows x 10 columns]

# %% [markdown]
# ##### Renaming the name of columns and convert datatype

# %%
SeventhColumn= dfSalesProductsInventoryMerged.pop('Gross Profit ($)')
dfSalesProductsInventoryMerged.insert(7,'Gross Profit ($)',SeventhColumn)
dfSalesProductsInventoryMerged.columns = ['Sales ID','Date Of Sales','Product Name', 'Product Category',
                                          'Product Cost ($)','Product Price ($)','Gross Profit ($)','Stock On Hand',
                                          'Store City','Store Open Date']

# %%
dfSalesProductsInventoryMerged
# Out:
#           Sales ID  \
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 26405705    821027
# 26405706    821027
# 26405708    821027
# 26405711    821027
# 26405713    821027
#
#          Date Of Sales  \
# 0           2017-01-01
# 1           2017-01-01
# 2           2017-01-01
# 3           2017-01-01
# 4           2017-01-01
# ...                ...
# 26405705    2018-09-25
# 26405706    2018-09-25
# 26405708    2018-09-25
# 26405711    2018-09-25
# 26405713    2018-09-25
#
#               Product Name  \
# 0         Chutes & Ladders
# 1         Chutes & Ladders
# 2         Chutes & Ladders
# 3         Chutes & Ladders
# 4         Chutes & Ladders
# ...                    ...
# 26405705          Playfoam
# 26405706          Playfoam
# 26405708          Playfoam
# 26405711          Playfoam
# 26405713          Playfoam
#
#          Product Category  \
# 0                   Games
# 1                   Games
# 2                   Games
# 3                   Games
# 4                   Games
# ...                   ...
# 26405705     Art & Crafts
# 26405706     Art & Crafts
# 26405708     Art & Crafts
# 26405711     Art & Crafts
# 26405713     Art & Crafts
#
#           Product Cost ($)  \
# 0                     9.99
# 1                     9.99
# 2                     9.99
# 3                     9.99
# 4                     9.99
# ...                    ...
# 26405705              3.99
# 26405706              3.99
# 26405708              3.99
# 26405711              3.99
# 26405713              3.99
#
#           Product Price ($)  \
# 0                     12.99
# 1                     12.99
# 2                     12.99
# 3                     12.99
# 4                     12.99
# ...                     ...
# 26405705              10.99
# 26405706              10.99
# 26405708              10.99
# 26405711              10.99
# 26405713              10.99
#
#           Gross Profit ($)  \
# 0                       11
# 1                       25
# 2                       13
# 3                        1
# 4                        4
# ...                    ...
# 26405705                24
# 26405706                37
# 26405708                56
# 26405711                17
# 26405713                 7
#
#           Stock On Hand  \
# 0                   3.0
# 1                   3.0
# 2                   3.0
# 3                   3.0
# 4                   3.0
# ...                 ...
# 26405705            7.0
# 26405706            7.0
# 26405708            7.0
# 26405711            7.0
# 26405713            7.0
#
#               Store City  \
# 0         Aguascalientes
# 1         Aguascalientes
# 2         Aguascalientes
# 3         Aguascalientes
# 4         Aguascalientes
# ...                  ...
# 26405705        Mexicali
# 26405706        Mexicali
# 26405708        Mexicali
# 26405711        Mexicali
# 26405713        Mexicali
#
#          Store Open Date
# 0             2010-07-31
# 1             2010-07-31
# 2             2010-07-31
# 3             2010-07-31
# 4             2010-07-31
# ...                  ...
# 26405705      2006-08-30
# 26405706      2006-08-30
# 26405708      2006-08-30
# 26405711      2006-08-30
# 26405713      2006-08-30
#
# [18222078 rows x 10 columns]

# %%
dfSalesProductsInventoryMerged.dtypes
# Out:
# Sales ID               int64
# Date Of Sales         object
# Product Name          object
# Product Category      object
# Product Cost ($)     float64
# Product Price ($)    float64
# Gross Profit ($)       int64
# Stock On Hand        float64
# Store City            object
# Store Open Date       object
# dtype: object

# %%
convert_dict = {
                'Sales ID': int,
                'Product Name': object, 
                'Product Category': object,
                'Product Cost ($)': float, 
                'Product Price ($)': float,
                'Gross Profit ($)': float,
                'Stock On Hand': int,
                'Store City': object
                    }
dfSalesProductsInventoryMerged = dfSalesProductsInventoryMerged.astype(convert_dict)
dfSalesProductsInventoryMerged[['Date Of Sales', 'Store Open Date']] = dfSalesProductsInventoryMerged[['Date Of Sales', 'Store Open Date']]\
                                                    .apply(pd.to_datetime)
dfSalesProductsInventoryMerged.dtypes
# Out:
# Sales ID                      int32
# Date Of Sales        datetime64[ns]
# Product Name                 object
# Product Category             object
# Product Cost ($)            float64
# Product Price ($)           float64
# Gross Profit ($)            float64
# Stock On Hand                 int32
# Store City                   object
# Store Open Date      datetime64[ns]
# dtype: object

# %%
dfSalesProductsInventoryMerged
# Out:
#           Sales ID  \
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 26405705    821027
# 26405706    821027
# 26405708    821027
# 26405711    821027
# 26405713    821027
#
#          Date Of Sales  \
# 0           2017-01-01
# 1           2017-01-01
# 2           2017-01-01
# 3           2017-01-01
# 4           2017-01-01
# ...                ...
# 26405705    2018-09-25
# 26405706    2018-09-25
# 26405708    2018-09-25
# 26405711    2018-09-25
# 26405713    2018-09-25
#
#               Product Name  \
# 0         Chutes & Ladders
# 1         Chutes & Ladders
# 2         Chutes & Ladders
# 3         Chutes & Ladders
# 4         Chutes & Ladders
# ...                    ...
# 26405705          Playfoam
# 26405706          Playfoam
# 26405708          Playfoam
# 26405711          Playfoam
# 26405713          Playfoam
#
#          Product Category  \
# 0                   Games
# 1                   Games
# 2                   Games
# 3                   Games
# 4                   Games
# ...                   ...
# 26405705     Art & Crafts
# 26405706     Art & Crafts
# 26405708     Art & Crafts
# 26405711     Art & Crafts
# 26405713     Art & Crafts
#
#           Product Cost ($)  \
# 0                     9.99
# 1                     9.99
# 2                     9.99
# 3                     9.99
# 4                     9.99
# ...                    ...
# 26405705              3.99
# 26405706              3.99
# 26405708              3.99
# 26405711              3.99
# 26405713              3.99
#
#           Product Price ($)  \
# 0                     12.99
# 1                     12.99
# 2                     12.99
# 3                     12.99
# 4                     12.99
# ...                     ...
# 26405705              10.99
# 26405706              10.99
# 26405708              10.99
# 26405711              10.99
# 26405713              10.99
#
#           Gross Profit ($)  \
# 0                     11.0
# 1                     25.0
# 2                     13.0
# 3                      1.0
# 4                      4.0
# ...                    ...
# 26405705              24.0
# 26405706              37.0
# 26405708              56.0
# 26405711              17.0
# 26405713               7.0
#
#           Stock On Hand  \
# 0                     3
# 1                     3
# 2                     3
# 3                     3
# 4                     3
# ...                 ...
# 26405705              7
# 26405706              7
# 26405708              7
# 26405711              7
# 26405713              7
#
#               Store City  \
# 0         Aguascalientes
# 1         Aguascalientes
# 2         Aguascalientes
# 3         Aguascalientes
# 4         Aguascalientes
# ...                  ...
# 26405705        Mexicali
# 26405706        Mexicali
# 26405708        Mexicali
# 26405711        Mexicali
# 26405713        Mexicali
#
#          Store Open Date
# 0             2010-07-31
# 1             2010-07-31
# 2             2010-07-31
# 3             2010-07-31
# 4             2010-07-31
# ...                  ...
# 26405705      2006-08-30
# 26405706      2006-08-30
# 26405708      2006-08-30
# 26405711      2006-08-30
# 26405713      2006-08-30
#
# [18222078 rows x 10 columns]

# %%
dfSalesProductsInventoryMerged['Year of Sales'] = pd.DatetimeIndex(dfSalesProductsInventoryMerged['Date Of Sales']).year
dfSalesProductsInventoryMerged['Month of Sales'] = pd.DatetimeIndex(dfSalesProductsInventoryMerged['Date Of Sales']).month
dfSalesProductsInventoryMerged['Month Name of Sales'] = dfSalesProductsInventoryMerged['Month of Sales'].apply(lambda x: calendar.month_abbr[x])
dfSalesProductsInventoryMerged
# Out:
#           Sales ID  \
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 26405705    821027
# 26405706    821027
# 26405708    821027
# 26405711    821027
# 26405713    821027
#
#          Date Of Sales  \
# 0           2017-01-01
# 1           2017-01-01
# 2           2017-01-01
# 3           2017-01-01
# 4           2017-01-01
# ...                ...
# 26405705    2018-09-25
# 26405706    2018-09-25
# 26405708    2018-09-25
# 26405711    2018-09-25
# 26405713    2018-09-25
#
#               Product Name  \
# 0         Chutes & Ladders
# 1         Chutes & Ladders
# 2         Chutes & Ladders
# 3         Chutes & Ladders
# 4         Chutes & Ladders
# ...                    ...
# 26405705          Playfoam
# 26405706          Playfoam
# 26405708          Playfoam
# 26405711          Playfoam
# 26405713          Playfoam
#
#          Product Category  \
# 0                   Games
# 1                   Games
# 2                   Games
# 3                   Games
# 4                   Games
# ...                   ...
# 26405705     Art & Crafts
# 26405706     Art & Crafts
# 26405708     Art & Crafts
# 26405711     Art & Crafts
# 26405713     Art & Crafts
#
#           Product Cost ($)  \
# 0                     9.99
# 1                     9.99
# 2                     9.99
# 3                     9.99
# 4                     9.99
# ...                    ...
# 26405705              3.99
# 26405706              3.99
# 26405708              3.99
# 26405711              3.99
# 26405713              3.99
#
#           Product Price ($)  \
# 0                     12.99
# 1                     12.99
# 2                     12.99
# 3                     12.99
# 4                     12.99
# ...                     ...
# 26405705              10.99
# 26405706              10.99
# 26405708              10.99
# 26405711              10.99
# 26405713              10.99
#
#           Gross Profit ($)  \
# 0                     11.0
# 1                     25.0
# 2                     13.0
# 3                      1.0
# 4                      4.0
# ...                    ...
# 26405705              24.0
# 26405706              37.0
# 26405708              56.0
# 26405711              17.0
# 26405713               7.0
#
#           Stock On Hand  \
# 0                     3
# 1                     3
# 2                     3
# 3                     3
# 4                     3
# ...                 ...
# 26405705              7
# 26405706              7
# 26405708              7
# 26405711              7
# 26405713              7
#
#               Store City  \
# 0         Aguascalientes
# 1         Aguascalientes
# 2         Aguascalientes
# 3         Aguascalientes
# 4         Aguascalientes
# ...                  ...
# 26405705        Mexicali
# 26405706        Mexicali
# 26405708        Mexicali
# 26405711        Mexicali
# 26405713        Mexicali
#
#          Store Open Date  \
# 0             2010-07-31
# 1             2010-07-31
# 2             2010-07-31
# 3             2010-07-31
# 4             2010-07-31
# ...                  ...
# 26405705      2006-08-30
# 26405706      2006-08-30
# 26405708      2006-08-30
# 26405711      2006-08-30
# 26405713      2006-08-30
#
#           Year of Sales  \
# 0                  2017
# 1                  2017
# 2                  2017
# 3                  2017
# 4                  2017
# ...                 ...
# 26405705           2018
# 26405706           2018
# 26405708           2018
# 26405711           2018
# 26405713           2018
#
#           Month of Sales  \
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 26405705               9
# 26405706               9
# 26405708               9
# 26405711               9
# 26405713               9
#
#          Month Name of Sales
# 0                        Jan
# 1                        Jan
# 2                        Jan
# 3                        Jan
# 4                        Jan
# ...                      ...
# 26405705                 Sep
# 26405706                 Sep
# 26405708                 Sep
# 26405711                 Sep
# 26405713                 Sep
#
# [18222078 rows x 13 columns]

# %%
dfSalesProductsInventoryMergedGroupedCount = dfSalesProductsInventoryMerged.groupby(['Year of Sales','Month of Sales','Month Name of Sales','Product Name']).aggregate({'Product Name':'count'})
dfSalesProductsInventoryMergedGroupedCount.rename(columns={'Product Name':'Quantity of Product Name'}, inplace=True)
dfSalesProductsInventoryMergedGroupedCount.reset_index(inplace=True)
dfSalesProductsInventoryMergedGroupedCount
# Out:
#      Year of Sales  \
# 0             2017
# 1             2017
# 2             2017
# 3             2017
# 4             2017
# ..             ...
# 644           2018
# 645           2018
# 646           2018
# 647           2018
# 648           2018
#
#      Month of Sales  \
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 644               9
# 645               9
# 646               9
# 647               9
# 648               9
#
#     Month Name of Sales  \
# 0                   Jan
# 1                   Jan
# 2                   Jan
# 3                   Jan
# 4                   Jan
# ..                  ...
# 644                 Sep
# 645                 Sep
# 646                 Sep
# 647                 Sep
# 648                 Sep
#
#               Product Name  \
# 0            Action Figure
# 1           Animal Figures
# 2          Barrel O' Slime
# 3         Chutes & Ladders
# 4         Classic Dominoes
# ..                     ...
# 644           Splash Balls
# 645  Supersoaker Water Gun
# 646             Teddy Bear
# 647              Toy Robot
# 648          Uno Card Game
#
#      Quantity of Product Name
# 0                       64209
# 1                       26909
# 2                        1689
# 3                        3746
# 4                        6519
# ..                        ...
# 644                     30240
# 645                      5077
# 646                      4694
# 647                     10206
# 648                      3409
#
# [649 rows x 5 columns]

# %%
YearOfSalesQuantityOfProductName = dfSalesProductsInventoryMerged.groupby(['Year of Sales','Product Name']).aggregate({'Product Name':'count'})
YearOfSalesQuantityOfProductName.rename(columns={'Product Name':'Quantity of Product Name'}, inplace=True)
YearOfSalesQuantityOfProductName.reset_index(inplace=True)
YearOfSalesQuantityOfProductName
# Out:
#     Year of Sales  \
# 0            2017
# 1            2017
# 2            2017
# 3            2017
# 4            2017
# ..            ...
# 63           2018
# 64           2018
# 65           2018
# 66           2018
# 67           2018
#
#              Product Name  \
# 0           Action Figure
# 1          Animal Figures
# 2         Barrel O' Slime
# 3        Chutes & Ladders
# 4        Classic Dominoes
# ..                    ...
# 63           Splash Balls
# 64  Supersoaker Water Gun
# 65             Teddy Bear
# 66              Toy Robot
# 67          Uno Card Game
#
#     Quantity of Product Name
# 0                     683857
# 1                     396748
# 2                     372377
# 3                      44958
# 4                      56165
# ..                       ...
# 63                    360312
# 64                     52512
# 65                     60069
# 66                     94093
# 67                     34391
#
# [68 rows x 3 columns]

# %%
YearOfSalesStoreCityProductNameQuantity = dfSalesProductsInventoryMerged.groupby(['Year of Sales','Store City','Product Name']).aggregate({'Product Name':'count'})
YearOfSalesStoreCityProductNameQuantity.rename(columns={'Product Name':'Quantity of Product Name'}, inplace=True)
YearOfSalesStoreCityProductNameQuantity.reset_index(inplace=True)
YearOfSalesStoreCityProductNameQuantity
# Out:
#       Year of Sales  \
# 0              2017
# 1              2017
# 2              2017
# 3              2017
# 4              2017
# ...             ...
# 1862           2018
# 1863           2018
# 1864           2018
# 1865           2018
# 1866           2018
#
#           Store City  \
# 0     Aguascalientes
# 1     Aguascalientes
# 2     Aguascalientes
# 3     Aguascalientes
# 4     Aguascalientes
# ...              ...
# 1862       Zacatecas
# 1863       Zacatecas
# 1864       Zacatecas
# 1865       Zacatecas
# 1866       Zacatecas
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4          Classic Dominoes
# ...                     ...
# 1862           Rubik's Cube
# 1863           Splash Balls
# 1864  Supersoaker Water Gun
# 1865             Teddy Bear
# 1866              Toy Robot
#
#       Quantity of Product Name
# 0                        10472
# 1                         5280
# 2                         6028
# 3                         1188
# 4                         3168
# ...                        ...
# 1862                      6720
# 1863                      5376
# 1864                      1323
# 1865                      2793
# 1866                       861
#
# [1867 rows x 4 columns]

# %%
dfSalesProductsInventoryMergedGrouped = dfSalesProductsInventoryMerged.groupby(['Year of Sales','Month of Sales','Month Name of Sales','Store City','Product Name'])[['Product Cost ($)','Product Price ($)','Gross Profit ($)','Stock On Hand']].sum()
dfSalesProductsInventoryMergedGrouped.reset_index(inplace=True)
dfSalesProductsInventoryMergedGrouped
# Out:
#        Year of Sales  \
# 0               2017
# 1               2017
# 2               2017
# 3               2017
# 4               2017
# ...              ...
# 14366           2018
# 14367           2018
# 14368           2018
# 14369           2018
# 14370           2018
#
#        Month of Sales  \
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 14366               9
# 14367               9
# 14368               9
# 14369               9
# 14370               9
#
#       Month Name of Sales  \
# 0                     Jan
# 1                     Jan
# 2                     Jan
# 3                     Jan
# 4                     Jan
# ...                   ...
# 14366                 Sep
# 14367                 Sep
# 14368                 Sep
# 14369                 Sep
# 14370                 Sep
#
#            Store City  \
# 0      Aguascalientes
# 1      Aguascalientes
# 2      Aguascalientes
# 3      Aguascalientes
# 4      Aguascalientes
# ...               ...
# 14366       Zacatecas
# 14367       Zacatecas
# 14368       Zacatecas
# 14369       Zacatecas
# 14370       Zacatecas
#
#                 Product Name  \
# 0              Action Figure
# 1             Animal Figures
# 2            Barrel O' Slime
# 3           Chutes & Ladders
# 4                  Colorbuds
# ...                      ...
# 14366               Playfoam
# 14367           Rubik's Cube
# 14368           Splash Balls
# 14369  Supersoaker Water Gun
# 14370             Teddy Bear
#
#        Product Cost ($)  \
# 0               9890.10
# 1               1098.90
# 2                525.36
# 3               3076.92
# 4              17684.70
# ...                 ...
# 14366           2094.75
# 14367          10955.91
# 14368           9228.45
# 14369           2769.69
# 14370           7385.28
#
#        Product Price ($)  \
# 0               15830.10
# 1                1428.90
# 2                1053.36
# 3                4000.92
# 4               37924.70
# ...                  ...
# 14366            5769.75
# 14367           12173.91
# 14368           10383.45
# 14369            3462.69
# 14370            8729.28
#
#        Gross Profit ($)  \
# 0               22905.0
# 1                2545.0
# 2                6108.0
# 3                7126.0
# 4               58535.0
# ...                 ...
# 14366           10500.0
# 14367           12180.0
# 14368           23100.0
# 14369            4620.0
# 14370           13440.0
#
#        Stock On Hand
# 0               5940
# 1                330
# 2                528
# 3                924
# 4              20240
# ...              ...
# 14366           3675
# 14367           1218
# 14368           1155
# 14369            693
# 14370           1344
#
# [14371 rows x 9 columns]

# %% [markdown]
# ##### Analysis of Sales 2017

# %%
dfSalesProductsInventoryMergedGrouped2017 = dfSalesProductsInventoryMergedGrouped.loc[dfSalesProductsInventoryMergedGrouped['Year of Sales']==2017]     
dfSalesProductsInventoryMergedGrouped2017
# Out:
#       Year of Sales  \
# 0              2017
# 1              2017
# 2              2017
# 3              2017
# 4              2017
# ...             ...
# 7350           2017
# 7351           2017
# 7352           2017
# 7353           2017
# 7354           2017
#
#       Month of Sales  \
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 7350              12
# 7351              12
# 7352              12
# 7353              12
# 7354              12
#
#      Month Name of Sales  \
# 0                    Jan
# 1                    Jan
# 2                    Jan
# 3                    Jan
# 4                    Jan
# ...                  ...
# 7350                 Dec
# 7351                 Dec
# 7352                 Dec
# 7353                 Dec
# 7354                 Dec
#
#           Store City  \
# 0     Aguascalientes
# 1     Aguascalientes
# 2     Aguascalientes
# 3     Aguascalientes
# 4     Aguascalientes
# ...              ...
# 7350       Zacatecas
# 7351       Zacatecas
# 7352       Zacatecas
# 7353       Zacatecas
# 7354       Zacatecas
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4                 Colorbuds
# ...                     ...
# 7350             Plush Pony
# 7351           Rubik's Cube
# 7352           Splash Balls
# 7353  Supersoaker Water Gun
# 7354              Toy Robot
#
#       Product Cost ($)  \
# 0              9890.10
# 1              1098.90
# 2               525.36
# 3              3076.92
# 4             17684.70
# ...                ...
# 7350            755.16
# 7351          24556.35
# 7352            838.95
# 7353           2014.32
# 7354           1322.37
#
#       Product Price ($)  \
# 0              15830.10
# 1               1428.90
# 2               1053.36
# 3               4000.92
# 4              37924.70
# ...                 ...
# 7350            1679.16
# 7351           27286.35
# 7352             943.95
# 7353            2518.32
# 7354            1637.37
#
#       Gross Profit ($)  \
# 0              22905.0
# 1               2545.0
# 2               6108.0
# 3               7126.0
# 4              58535.0
# ...                ...
# 7350            1680.0
# 7351           27300.0
# 7352            2100.0
# 7353            3360.0
# 7354            1260.0
#
#       Stock On Hand
# 0              5940
# 1               330
# 2               528
# 3               924
# 4             20240
# ...             ...
# 7350            840
# 7351           2730
# 7352            105
# 7353            504
# 7354            315
#
# [7355 rows x 9 columns]

# %%
SummaryOfdfSalesProductsInventoryMergedGrouped2017 = dfSalesProductsInventoryMergedGrouped2017.groupby(['Year of Sales','Month of Sales','Month Name of Sales']).sum()
SummaryOfdfSalesProductsInventoryMergedGrouped2017.reset_index(inplace=True)
SummaryOfdfSalesProductsInventoryMergedGrouped2017.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_07c4a_row0_col0, #T_07c4a_row0_col1, #T_07c4a_row1_col0, #T_07c4a_row1_col5, #T_07c4a_row1_col6, #T_07c4a_row2_col0, #T_07c4a_row3_col0, #T_07c4a_row4_col0, #T_07c4a_row5_col0, #T_07c4a_row6_col0, #T_07c4a_row7_col0, #T_07c4a_row7_col3, #T_07c4a_row7_col4, #T_07c4a_row8_col0, #T_07c4a_row9_col0, #T_07c4a_row10_col0, #T_07c4a_row11_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_07c4a_row0_col3 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_07c4a_row0_col4, #T_07c4a_row1_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_07c4a_row0_col5 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_07c4a_row0_col6 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_07c4a_row1_col3 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_07c4a_row1_col4 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_07c4a_row2_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_07c4a_row2_col3 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_07c4a_row2_col4 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_07c4a_row2_col5 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_07c4a_row2_col6, #T_07c4a_row7_col5 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_07c4a_row3_col1 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_07c4a_row3_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_07c4a_row3_col4, #T_07c4a_row5_col3, #T_07c4a_row9_col5 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_07c4a_row3_col5 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_07c4a_row3_col6 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_07c4a_row4_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_07c4a_row4_col3, #T_07c4a_row10_col3 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_07c4a_row4_col4 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_07c4a_row4_col5 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_07c4a_row4_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_07c4a_row5_col1, #T_07c4a_row10_col6 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_07c4a_row5_col4 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_07c4a_row5_col5 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_07c4a_row5_col6 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_07c4a_row6_col1 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_07c4a_row6_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_07c4a_row6_col4 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_07c4a_row6_col5 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_07c4a_row6_col6 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_07c4a_row7_col1 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_07c4a_row7_col6 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_07c4a_row8_col1 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_07c4a_row8_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_07c4a_row8_col4 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_07c4a_row8_col5 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_07c4a_row8_col6 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_07c4a_row9_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_07c4a_row9_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_07c4a_row9_col4 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_07c4a_row9_col6 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_07c4a_row10_col1 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_07c4a_row10_col4 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_07c4a_row10_col5 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_07c4a_row11_col1, #T_07c4a_row11_col3, #T_07c4a_row11_col4, #T_07c4a_row11_col5, #T_07c4a_row11_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_07c4a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07c4a_level0_col0" class="col_heading level0 col0" >Year of Sales</th>
#       <th id="T_07c4a_level0_col1" class="col_heading level0 col1" >Month of Sales</th>
#       <th id="T_07c4a_level0_col2" class="col_heading level0 col2" >Month Name of Sales</th>
#       <th id="T_07c4a_level0_col3" class="col_heading level0 col3" >Product Cost ($)</th>
#       <th id="T_07c4a_level0_col4" class="col_heading level0 col4" >Product Price ($)</th>
#       <th id="T_07c4a_level0_col5" class="col_heading level0 col5" >Gross Profit ($)</th>
#       <th id="T_07c4a_level0_col6" class="col_heading level0 col6" >Stock On Hand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07c4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07c4a_row0_col0" class="data row0 col0" >2017</td>
#       <td id="T_07c4a_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_07c4a_row0_col2" class="data row0 col2" >Jan</td>
#       <td id="T_07c4a_row0_col3" class="data row0 col3" >6573460.400000</td>
#       <td id="T_07c4a_row0_col4" class="data row0 col4" >9285416.400000</td>
#       <td id="T_07c4a_row0_col5" class="data row0 col5" >14341058.000000</td>
#       <td id="T_07c4a_row0_col6" class="data row0 col6" >2666184</td>
#     </tr>
#     <tr>
#       <th id="T_07c4a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07c4a_row1_col0" class="data row1 col0" >2017</td>
#       <td id="T_07c4a_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_07c4a_row1_col2" class="data row1 col2" >Feb</td>
#       <td id="T_07c4a_row1_col3" class="data row1 col3" >6589169.240000</td>
#       <td id="T_07c4a_row1_col4" class="data row1 col4" >9273880.240000</td>
#       <td id="T_07c4a_row1_col5" class="data row1 col5" >13956047.000000</td>
#       <td id="T_07c4a_row1_col6" class="data row1 col6" >2643072</td>
#     </tr>
#     <tr>
#       <th id="T_07c4a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07c4a_row2_col0" class="data row2 col0" >2017</td>
#       <td id="T_07c4a_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_07c4a_row2_col2" class="data row2 col2" >Mar</td>
#       <td id="T_07c4a_row2_col3" class="data row2 col3" >7222912.850000</td>
#       <td id="T_07c4a_row2_col4" class="data row2 col4" >10133181.850000</td>
#       <td id="T_07c4a_row2_col5" class="data row2 col5" >15268556.000000</td>
#       <td id="T_07c4a_row2_col6" class="data row2 col6" >2857438</td>
#     </tr>
#     <tr>
#       <th id="T_07c4a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07c4a_row3_col0" class="data row3 col0" >2017</td>
#       <td id="T_07c4a_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_07c4a_row3_col2" class="data row3 col2" >Apr</td>
#       <td id="T_07c4a_row3_col3" class="data row3 col3" >8139915.340000</td>
#       <td id="T_07c4a_row3_col4" class="data row3 col4" >11247813.340000</td>
#       <td id="T_07c4a_row3_col5" class="data row3 col5" >17389364.000000</td>
#       <td id="T_07c4a_row3_col6" class="data row3 col6" >3045486</td>
#     </tr>
#     <tr>
#       <th id="T_07c4a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07c4a_row4_col0" class="data row4 col0" >2017</td>
#       <td id="T_07c4a_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_07c4a_row4_col2" class="data row4 col2" >May</td>
#       <td id="T_07c4a_row4_col3" class="data row4 col3" >8453706.040000</td>
#       <td id="T_07c4a_row4_col4" class="data row4 col4" >11704423.040000</td>
#       <td id="T_07c4a_row4_col5" class="data row4 col5" >18180855.000000</td>
#       <td id="T_07c4a_row4_col6" class="data row4 col6" >3185843</td>
#     </tr>
#     <tr>
#       <th id="T_07c4a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_07c4a_row5_col0" class="data row5 col0" >2017</td>
#       <td id="T_07c4a_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_07c4a_row5_col2" class="data row5 col2" >Jun</td>
#       <td id="T_07c4a_row5_col3" class="data row5 col3" >7908921.830000</td>
#       <td id="T_07c4a_row5_col4" class="data row5 col4" >11136543.830000</td>
#       <td id="T_07c4a_row5_col5" class="data row5 col5" >17466949.0000

# %%
MaxProductCost = SummaryOfdfSalesProductsInventoryMergedGrouped2017[SummaryOfdfSalesProductsInventoryMergedGrouped2017['Product Cost ($)']==SummaryOfdfSalesProductsInventoryMergedGrouped2017['Product Cost ($)'].max()]
MaxProductPrice = SummaryOfdfSalesProductsInventoryMergedGrouped2017[SummaryOfdfSalesProductsInventoryMergedGrouped2017['Product Price ($)']==SummaryOfdfSalesProductsInventoryMergedGrouped2017['Product Price ($)'].max()]
MaxGrossProift = SummaryOfdfSalesProductsInventoryMergedGrouped2017[SummaryOfdfSalesProductsInventoryMergedGrouped2017['Gross Profit ($)']==SummaryOfdfSalesProductsInventoryMergedGrouped2017['Gross Profit ($)'].max()]
MaxStockOnHand = SummaryOfdfSalesProductsInventoryMergedGrouped2017[SummaryOfdfSalesProductsInventoryMergedGrouped2017['Stock On Hand']==SummaryOfdfSalesProductsInventoryMergedGrouped2017['Stock On Hand'].max()]

# %%
MaxProductCost
# Out:
#     Year of Sales  \
# 11           2017
#
#     Month of Sales  \
# 11              12
#
#    Month Name of Sales  \
# 11                 Dec
#
#     Product Cost ($)  \
# 11       10795351.59
#
#     Product Price ($)  \
# 11        14954667.59
#
#     Gross Profit ($)  \
# 11        23644517.0
#
#     Stock On Hand
# 11        4020883

# %%
MinProductCost = SummaryOfdfSalesProductsInventoryMergedGrouped2017[SummaryOfdfSalesProductsInventoryMergedGrouped2017['Product Cost ($)']==SummaryOfdfSalesProductsInventoryMergedGrouped2017['Product Cost ($)'].min()]
MinProductPrice = SummaryOfdfSalesProductsInventoryMergedGrouped2017[SummaryOfdfSalesProductsInventoryMergedGrouped2017['Product Price ($)']==SummaryOfdfSalesProductsInventoryMergedGrouped2017['Product Price ($)'].min()]
MinGrossProift = SummaryOfdfSalesProductsInventoryMergedGrouped2017[SummaryOfdfSalesProductsInventoryMergedGrouped2017['Gross Profit ($)']==SummaryOfdfSalesProductsInventoryMergedGrouped2017['Gross Profit ($)'].min()]
MinStockOnHand = SummaryOfdfSalesProductsInventoryMergedGrouped2017[SummaryOfdfSalesProductsInventoryMergedGrouped2017['Stock On Hand']==SummaryOfdfSalesProductsInventoryMergedGrouped2017['Stock On Hand'].min()]

# %%
MinProductCost
# Out:
#    Year of Sales  \
# 7           2017
#
#    Month of Sales  \
# 7               8
#
#   Month Name of Sales  \
# 7                 Aug
#
#    Product Cost ($)  \
# 7        5953599.19
#
#    Product Price ($)  \
# 7         8716941.19
#
#    Gross Profit ($)  \
# 7        15438462.0
#
#    Stock On Hand
# 7        2708776

# %%
MinStockOnHand
# Out:
#    Year of Sales  \
# 1           2017
#
#    Month of Sales  \
# 1               2
#
#   Month Name of Sales  \
# 1                 Feb
#
#    Product Cost ($)  \
# 1        6589169.24
#
#    Product Price ($)  \
# 1         9273880.24
#
#    Gross Profit ($)  \
# 1        13956047.0
#
#    Stock On Hand
# 1        2643072

# %%
SummaryOfdfSalesProductsInventoryMergedGrouped2017[(SummaryOfdfSalesProductsInventoryMergedGrouped2017['Gross Profit ($)']>17000000)]
# Out:
#     Year of Sales  \
# 3            2017
# 4            2017
# 5            2017
# 6            2017
# 9            2017
# 10           2017
# 11           2017
#
#     Month of Sales  \
# 3                4
# 4                5
# 5                6
# 6                7
# 9               10
# 10              11
# 11              12
#
#    Month Name of Sales  \
# 3                  Apr
# 4                  May
# 5                  Jun
# 6                  Jul
# 9                  Oct
# 10                 Nov
# 11                 Dec
#
#     Product Cost ($)  \
# 3         8139915.34
# 4         8453706.04
# 5         7908921.83
# 6         6524895.01
# 9         7920619.93
# 10        8456404.57
# 11       10795351.59
#
#     Product Price ($)  \
# 3         11247813.34
# 4         11704423.04
# 5         11136543.83
# 6          9579015.01
# 9         11031140.93
# 10        11812964.57
# 11        14954667.59
#
#     Gross Profit ($)  \
# 3         17389364.0
# 4         18180855.0
# 5         17466949.0
# 6         17195567.0
# 9         17876589.0
# 10        19054092.0
# 11        23644517.0
#
#     Stock On Hand
# 3         3045486
# 4         3185843
# 5         3169810
# 6         2995041
# 9         3040237
# 10        3268049
# 11        4020883

# %%
SummaryOfdfSalesProductsInventoryMergedGrouped2017[(SummaryOfdfSalesProductsInventoryMergedGrouped2017['Gross Profit ($)']>17000000) & (SummaryOfdfSalesProductsInventoryMergedGrouped2017['Stock On Hand']>3100000)]
# Out:
#     Year of Sales  \
# 4            2017
# 5            2017
# 10           2017
# 11           2017
#
#     Month of Sales  \
# 4                5
# 5                6
# 10              11
# 11              12
#
#    Month Name of Sales  \
# 4                  May
# 5                  Jun
# 10                 Nov
# 11                 Dec
#
#     Product Cost ($)  \
# 4         8453706.04
# 5         7908921.83
# 10        8456404.57
# 11       10795351.59
#
#     Product Price ($)  \
# 4         11704423.04
# 5         11136543.83
# 10        11812964.57
# 11        14954667.59
#
#     Gross Profit ($)  \
# 4         18180855.0
# 5         17466949.0
# 10        19054092.0
# 11        23644517.0
#
#     Stock On Hand
# 4         3185843
# 5         3169810
# 10        3268049
# 11        4020883

# %%
#plot lines
x = SummaryOfdfSalesProductsInventoryMergedGrouped2017['Month Name of Sales']
y1 = SummaryOfdfSalesProductsInventoryMergedGrouped2017['Product Cost ($)'] / 1000000
y2 = SummaryOfdfSalesProductsInventoryMergedGrouped2017['Product Price ($)'] / 1000000
y3 = SummaryOfdfSalesProductsInventoryMergedGrouped2017['Gross Profit ($)'] /1000000 
plt.style.use('seaborn-poster')
plt.plot(x, y1, label='Product Cost ($)')
plt.plot(x, y2, label='Product Price ($)')
plt.plot(x, y3, label='Gross Profit ($)')
plt.ticklabel_format(style='plain', axis='y')
plt.xlabel('Month')
plt.ylabel('Money [mln] ($)')
plt.legend()
plt.show()

# %%
#plot lines
x = SummaryOfdfSalesProductsInventoryMergedGrouped2017['Month Name of Sales']
y4 = SummaryOfdfSalesProductsInventoryMergedGrouped2017['Stock On Hand'] / 1000000
plt.style.use('ggplot')

plt.plot(x, y4, label='Stock On Hand')
plt.ticklabel_format(style='plain', axis='y')
plt.xlabel('Month')
plt.ylabel('Stock On Hand [mln]')
plt.legend()
plt.show()

# %% [markdown]
# ##### Quantity of Products

# %%
YearOfSalesQuantityOfProductName2017 =YearOfSalesQuantityOfProductName.loc[YearOfSalesQuantityOfProductName['Year of Sales']==2017]
SelectedColumnsYearOfSalesQuantityOfProductName2017 = YearOfSalesQuantityOfProductName2017[['Product Name','Quantity of Product Name']].sort_values(by='Quantity of Product Name', ascending=False)
SelectedColumnsYearOfSalesQuantityOfProductName2017

#using filter to exercise
# Out:
#             Product Name  \
# 5              Colorbuds
# 7          Deck Of Cards
# 23           PlayDoh Can
# 0          Action Figure
# 16           Lego Bricks
# ..                   ...
# 3       Chutes & Ladders
# 21        Mr. Potatohead
# 18  Mini Basketball Hoop
# 20              Monopoly
# 32         Uno Card Game
#
#     Quantity of Product Name
# 5                    1115092
# 7                     852269
# 23                    698724
# 0                     683857
# 16                    572605
# ..                       ...
# 3                      44958
# 21                     41873
# 18                     39317
# 20                     31872
# 32                     26391
#
# [33 rows x 2 columns]

# %%
SelectedColumnsYearOfSalesQuantityOfProductName2017[SelectedColumnsYearOfSalesQuantityOfProductName2017['Quantity of Product Name']>400000]
# Out:
#      Product Name  \
# 5       Colorbuds
# 7   Deck Of Cards
# 23    PlayDoh Can
# 0   Action Figure
# 16    Lego Bricks
# 28   Splash Balls
# 27   Rubik's Cube
#
#     Quantity of Product Name
# 5                    1115092
# 7                     852269
# 23                    698724
# 0                     683857
# 16                    572605
# 28                    553324
# 27                    448454

# %%
SelectedColumnsYearOfSalesQuantityOfProductName2017.nsmallest(5,'Quantity of Product Name')
# Out:
#             Product Name  \
# 32         Uno Card Game
# 20              Monopoly
# 18  Mini Basketball Hoop
# 21        Mr. Potatohead
# 3       Chutes & Ladders
#
#     Quantity of Product Name
# 32                     26391
# 20                     31872
# 18                     39317
# 21                     41873
# 3                      44958

# %%
x =SelectedColumnsYearOfSalesQuantityOfProductName2017['Product Name']
y = SelectedColumnsYearOfSalesQuantityOfProductName2017['Quantity of Product Name']


fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.barh(x, y)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('Quantity of Product Name 2017',
             loc ='left', )
 
# Add Text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
         color ='grey', ha ='right', va ='bottom',
         alpha = 0.7)
 
# Show Plot
plt.show()
# Out:
# C:\Users\dlugo\AppData\Local\Temp\ipykernel_16204\2118399396.py:27: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b = True, color ='grey',

# %%
dfSalesProductsInventoryMergedGroupedCount2017 =dfSalesProductsInventoryMergedGroupedCount.loc[dfSalesProductsInventoryMergedGroupedCount['Year of Sales']==2017]
dfSalesProductsInventoryMergedGroupedCount2017
# Out:
#      Year of Sales  \
# 0             2017
# 1             2017
# 2             2017
# 3             2017
# 4             2017
# ..             ...
# 338           2017
# 339           2017
# 340           2017
# 341           2017
# 342           2017
#
#      Month of Sales  \
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 338              12
# 339              12
# 340              12
# 341              12
# 342              12
#
#     Month Name of Sales  \
# 0                   Jan
# 1                   Jan
# 2                   Jan
# 3                   Jan
# 4                   Jan
# ..                  ...
# 338                 Dec
# 339                 Dec
# 340                 Dec
# 341                 Dec
# 342                 Dec
#
#               Product Name  \
# 0            Action Figure
# 1           Animal Figures
# 2          Barrel O' Slime
# 3         Chutes & Ladders
# 4         Classic Dominoes
# ..                     ...
# 338           Splash Balls
# 339  Supersoaker Water Gun
# 340             Teddy Bear
# 341              Toy Robot
# 342          Uno Card Game
#
#      Quantity of Product Name
# 0                       64209
# 1                       26909
# 2                        1689
# 3                        3746
# 4                        6519
# ..                        ...
# 338                     31115
# 339                      3924
# 340                      8197
# 341                     11908
# 342                      5788
#
# [343 rows x 5 columns]

# %%
dfSalesProductsInventoryMergedGroupedCount2017['max'] = dfSalesProductsInventoryMergedGroupedCount2017.groupby('Month Name of Sales')['Quantity of Product Name'].transform("max")
dfSalesProductsInventoryMergedGroupedCount2017[['Month Name of Sales','max']].drop_duplicates(subset=['Month Name of Sales'])
# Out:
# C:\Users\dlugo\AppData\Local\Temp\ipykernel_16204\1535639739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSalesProductsInventoryMergedGroupedCount2017['max'] = dfSalesProductsInventoryMergedGroupedCount2017.groupby('Month Name of Sales')['Quantity of Product Name'].transform("max")
#     Month Name of Sales  \
# 0                   Jan
# 24                  Feb
# 48                  Mar
# 73                  Apr
# 98                  May
# 125                 Jun
# 153                 Jul
# 184                 Aug
# 215                 Sep
# 246                 Oct
# 277                 Nov
# 310                 Dec
#
#         max
# 0    110489
# 24   111266
# 48   112178
# 73   103066
# 98   103674
# 125   96431
# 153   97549
# 184   95384
# 215   76810
# 246   89334
# 277  101142
# 310  104036

# %%
dfSalesProductsInventoryMergedGroupedCount2017['min'] = dfSalesProductsInventoryMergedGroupedCount2017.groupby('Month Name of Sales')['Quantity of Product Name'].transform("min")
dfSalesProductsInventoryMergedGroupedCount2017[['Month Name of Sales','min']].drop_duplicates(subset=['Month Name of Sales'])
# Out:
# C:\Users\dlugo\AppData\Local\Temp\ipykernel_16204\190586033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSalesProductsInventoryMergedGroupedCount2017['min'] = dfSalesProductsInventoryMergedGroupedCount2017.groupby('Month Name of Sales')['Quantity of Product Name'].transform("min")
#     Month Name of Sales  \
# 0                   Jan
# 24                  Feb
# 48                  Mar
# 73                  Apr
# 98                  May
# 125                 Jun
# 153                 Jul
# 184                 Aug
# 215                 Sep
# 246                 Oct
# 277                 Nov
# 310                 Dec
#
#       min
# 0     912
# 24     75
# 48    171
# 73    422
# 98    125
# 125  2731
# 153   125
# 184  1031
# 215   724
# 246  1300
# 277    50
# 310  3924

# %%
max1 = dfSalesProductsInventoryMergedGroupedCount2017.groupby('Month Name of Sales')['Quantity of Product Name'].transform("max")

dfSalesProductsInventoryMergedGroupedCount2017[dfSalesProductsInventoryMergedGroupedCount2017['Quantity of Product Name']==max1]
# Out:
#      Year of Sales  \
# 5             2017
# 29            2017
# 52            2017
# 77            2017
# 102           2017
# 129           2017
# 158           2017
# 189           2017
# 220           2017
# 248           2017
# 279           2017
# 312           2017
#
#      Month of Sales  \
# 5                 1
# 29                2
# 52                3
# 77                4
# 102               5
# 129               6
# 158               7
# 189               8
# 220               9
# 248              10
# 279              11
# 312              12
#
#     Month Name of Sales  \
# 5                   Jan
# 29                  Feb
# 52                  Mar
# 77                  Apr
# 102                 May
# 129                 Jun
# 158                 Jul
# 189                 Aug
# 220                 Sep
# 248                 Oct
# 279                 Nov
# 312                 Dec
#
#         Product Name  \
# 5          Colorbuds
# 29         Colorbuds
# 52         Colorbuds
# 77         Colorbuds
# 102        Colorbuds
# 129        Colorbuds
# 158        Colorbuds
# 189        Colorbuds
# 220        Colorbuds
# 248  Barrel O' Slime
# 279  Barrel O' Slime
# 312  Barrel O' Slime
#
#      Quantity of Product Name  \
# 5                      110489
# 29                     111266
# 52                     112178
# 77                     103066
# 102                    103674
# 129                     96431
# 158                     97549
# 189                     95384
# 220                     76810
# 248                     89334
# 279                    101142
# 312                    104036
#
#         max   min
# 5    110489   912
# 29   111266    75
# 52   112178   171
# 77   103066   422
# 102  103674   125
# 129   96431  2731
# 158   97549   125
# 189   95384  1031
# 220   76810   724
# 248   89334  1300
# 279  101142    50
# 312  104036  3924

# %%
dfSalesProductsInventoryMergedGroupedCount2017.groupby('Month Name of Sales')['Quantity of Product Name'].transform("max")

# %%
a = dfSalesProductsInventoryMergedGroupedCount2017[dfSalesProductsInventoryMergedGroupedCount2017['Quantity of Product Name']==dfSalesProductsInventoryMergedGroupedCount2017.groupby('Month Name of Sales')['Quantity of Product Name'].transform("max")]

# %%
a
# Out:
#      Year of Sales  \
# 5             2017
# 29            2017
# 52            2017
# 77            2017
# 102           2017
# 129           2017
# 158           2017
# 189           2017
# 220           2017
# 248           2017
# 279           2017
# 312           2017
#
#      Month of Sales  \
# 5                 1
# 29                2
# 52                3
# 77                4
# 102               5
# 129               6
# 158               7
# 189               8
# 220               9
# 248              10
# 279              11
# 312              12
#
#     Month Name of Sales  \
# 5                   Jan
# 29                  Feb
# 52                  Mar
# 77                  Apr
# 102                 May
# 129                 Jun
# 158                 Jul
# 189                 Aug
# 220                 Sep
# 248                 Oct
# 279                 Nov
# 312                 Dec
#
#         Product Name  \
# 5          Colorbuds
# 29         Colorbuds
# 52         Colorbuds
# 77         Colorbuds
# 102        Colorbuds
# 129        Colorbuds
# 158        Colorbuds
# 189        Colorbuds
# 220        Colorbuds
# 248  Barrel O' Slime
# 279  Barrel O' Slime
# 312  Barrel O' Slime
#
#      Quantity of Product Name  \
# 5                      110489
# 29                     111266
# 52                     112178
# 77                     103066
# 102                    103674
# 129                     96431
# 158                     97549
# 189                     95384
# 220                     76810
# 248                     89334
# 279                    101142
# 312                    104036
#
#         max
# 5    110489
# 29   111266
# 52   112178
# 77   103066
# 102  103674
# 129   96431
# 158   97549
# 189   95384
# 220   76810
# 248   89334
# 279  101142
# 312  104036

# %%
b= dfSalesProductsInventoryMergedGroupedCount2017[dfSalesProductsInventoryMergedGroupedCount2017['Quantity of Product Name']==dfSalesProductsInventoryMergedGroupedCount2017.groupby('Month Name of Sales')['Quantity of Product Name'].transform("min")]

# %%
b
# Out:
#      Year of Sales  \
# 23            2017
# 47            2017
# 63            2017
# 75            2017
# 100           2017
# 140           2017
# 169           2017
# 212           2017
# 234           2017
# 276           2017
# 285           2017
# 339           2017
#
#      Month of Sales  \
# 23                1
# 47                2
# 63                3
# 75                4
# 100               5
# 140               6
# 169               7
# 212               8
# 234               9
# 276              10
# 285              11
# 339              12
#
#     Month Name of Sales  \
# 23                  Jan
# 47                  Feb
# 63                  Mar
# 75                  Apr
# 100                 May
# 140                 Jun
# 169                 Jul
# 212                 Aug
# 234                 Sep
# 276                 Oct
# 285                 Nov
# 339                 Dec
#
#               Product Name  \
# 23           Uno Card Game
# 47           Uno Card Game
# 63                Monopoly
# 75        Chutes & Ladders
# 100       Chutes & Ladders
# 140     Mini Ping Pong Set
# 169             Magic Sand
# 212             Teddy Bear
# 234         Mr. Potatohead
# 276          Uno Card Game
# 285               Dino Egg
# 339  Supersoaker Water Gun
#
#      Quantity of Product Name  \
# 23                        912
# 47                         75
# 63                        171
# 75                        422
# 100                       125
# 140                      2731
# 169                       125
# 212                      1031
# 234                       724
# 276                      1300
# 285                        50
# 339                      3924
#
#         max
# 23   110489
# 47   111266
# 63   112178
# 75   103066
# 100  103674
# 140   96431
# 169   97549
# 212   95384
# 234   76810
# 276   89334
# 285  101142
# 339  104036

# %%
dfSalesProductsInventoryMergedGroupedCount2017.groupby(['Year of Sales','Month of Sales','Month Name of Sales']).sum()
# Out:
#                                                   Quantity of Product Name
# Year of Sales Month of Sales Month Name of Sales
# 2017          1              Jan                                    646660
#               2              Feb                                    627876
#               3              Mar                                    685915
#               4              Apr                                    785266
#               5              May                                    813796
#               6              Jun                                    780617
#               7              Jul                                    766199
#               8              Aug                                    687781
#               9              Sep                                    726361
#               10             Oct                                    803807
#               11             Nov                                    854843
#               12             Dec                                   1063641

# %%
YearOfSalesStoreCityProductNameQuantity2017 = YearOfSalesStoreCityProductNameQuantity.loc[YearOfSalesStoreCityProductNameQuantity['Year of Sales']==2017]
YearOfSalesStoreCityProductNameQuantity2017
# Out:
#      Year of Sales  \
# 0             2017
# 1             2017
# 2             2017
# 3             2017
# 4             2017
# ..             ...
# 907           2017
# 908           2017
# 909           2017
# 910           2017
# 911           2017
#
#          Store City  \
# 0    Aguascalientes
# 1    Aguascalientes
# 2    Aguascalientes
# 3    Aguascalientes
# 4    Aguascalientes
# ..              ...
# 907       Zacatecas
# 908       Zacatecas
# 909       Zacatecas
# 910       Zacatecas
# 911       Zacatecas
#
#               Product Name  \
# 0            Action Figure
# 1           Animal Figures
# 2          Barrel O' Slime
# 3         Chutes & Ladders
# 4         Classic Dominoes
# ..                     ...
# 907           Rubik's Cube
# 908           Splash Balls
# 909  Supersoaker Water Gun
# 910             Teddy Bear
# 911              Toy Robot
#
#      Quantity of Product Name
# 0                       10472
# 1                        5280
# 2                        6028
# 3                        1188
# 4                        3168
# ..                        ...
# 907                      8169
# 908                      7203
# 909                      1533
# 910                      1239
# 911                      2289
#
# [912 rows x 4 columns]

# %%
dfSalesProductsInventoryMergedGrouped2017.groupby(['Year of Sales','Month of Sales','Month Name of Sales','Store City','Product Name']).sum().reset_index(inplace=True)
dfSalesProductsInventoryMergedGrouped2017
# Out:
#       Year of Sales  \
# 0              2017
# 1              2017
# 2              2017
# 3              2017
# 4              2017
# ...             ...
# 7350           2017
# 7351           2017
# 7352           2017
# 7353           2017
# 7354           2017
#
#       Month of Sales  \
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 7350              12
# 7351              12
# 7352              12
# 7353              12
# 7354              12
#
#      Month Name of Sales  \
# 0                    Jan
# 1                    Jan
# 2                    Jan
# 3                    Jan
# 4                    Jan
# ...                  ...
# 7350                 Dec
# 7351                 Dec
# 7352                 Dec
# 7353                 Dec
# 7354                 Dec
#
#           Store City  \
# 0     Aguascalientes
# 1     Aguascalientes
# 2     Aguascalientes
# 3     Aguascalientes
# 4     Aguascalientes
# ...              ...
# 7350       Zacatecas
# 7351       Zacatecas
# 7352       Zacatecas
# 7353       Zacatecas
# 7354       Zacatecas
#
#                Product Name  \
# 0             Action Figure
# 1            Animal Figures
# 2           Barrel O' Slime
# 3          Chutes & Ladders
# 4                 Colorbuds
# ...                     ...
# 7350             Plush Pony
# 7351           Rubik's Cube
# 7352           Splash Balls
# 7353  Supersoaker Water Gun
# 7354              Toy Robot
#
#       Product Cost ($)  \
# 0              9890.10
# 1              1098.90
# 2               525.36
# 3              3076.92
# 4             17684.70
# ...                ...
# 7350            755.16
# 7351          24556.35
# 7352            838.95
# 7353           2014.32
# 7354           1322.37
#
#       Product Price ($)  \
# 0              15830.10
# 1               1428.90
# 2               1053.36
# 3               4000.92
# 4              37924.70
# ...                 ...
# 7350            1679.16
# 7351           27286.35
# 7352             943.95
# 7353            2518.32
# 7354            1637.37
#
#       Gross Profit ($)  \
# 0              22905.0
# 1               2545.0
# 2               6108.0
# 3               7126.0
# 4              58535.0
# ...                ...
# 7350            1680.0
# 7351           27300.0
# 7352            2100.0
# 7353            3360.0
# 7354            1260.0
#
#       Stock On Hand
# 0              5940
# 1               330
# 2               528
# 3               924
# 4             20240
# ...             ...
# 7350            840
# 7351           2730
# 7352            105
# 7353            504
# 7354            315
#
# [7355 rows x 9 columns]

# %%
dfSalesProductsInventoryMergedGrouped2017.columns
# Out:
# Index(['Year of Sales',
#        'Month of Sales',
#        'Month Name of Sales',
#        'Store City',
#        'Product Name',
#        'Product Cost ($)',
#        'Product Price ($)',
#        'Gross Profit ($)',
#        'Stock On Hand'],
#       dtype='object')

# %%
dfSalesProductsInventoryMergedGrouped2017.groupby('Store City')\
        ['Product Cost ($)','Product Price ($)',
         'Gross Profit ($)','Stock On Hand'].sum()
# Out:
# C:\Users\dlugo\AppData\Local\Temp\ipykernel_16204\4091139316.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dfSalesProductsInventoryMergedGrouped2017.groupby('Store City')\
#                   Product Cost ($)  \
# Store City
# Aguascalientes          1760686.18
# Campeche                2875584.75
# Chetumal                1545653.80
# Chihuahua               3595938.32
# Chilpancingo            1570364.25
# ...                            ...
# Toluca                  3567566.20
# Tuxtla Gutierrez        1511221.92
# Villahermosa            1840356.24
# Xalapa                  3712222.45
# Zacatecas               1432298.91
#
#                   Product Price ($)  \
# Store City
# Aguascalientes           2459494.18
# Campeche                 4123193.75
# Chetumal                 2143673.80
# Chihuahua                5136298.32
# Chilpancingo             2210066.25
# ...                             ...
# Toluca                   4916970.20
# Tuxtla Gutierrez         2172517.92
# Villahermosa             2651364.24
# Xalapa                   5253412.45
# Zacatecas                1947218.91
#
#                   Gross Profit ($)  \
# Store City
# Aguascalientes           4011429.0
# Campeche                 6556545.0
# Chetumal                 3434136.0
# Chihuahua                9362446.0
# Chilpancingo             3939000.0
# ...                            ...
# Toluca                   7121404.0
# Tuxtla Gutierrez         3592032.0
# Villahermosa             5120094.0
# Xalapa                   7163647.0
# Zacatecas                2658180.0
#
#                   Stock On Hand
# Store City
# Aguascalientes           687236
# Campeche                1221262
# Chetumal                 588120
# Chihuahua               1506803
# Chilpancingo             630525
# ...                         ...
# Toluca                  1310916
# Tuxtla Gutierrez         648960
# Villahermosa             790872
# Xalapa                  1511003
# Zacatecas                505155
#
# [29 rows x 4 columns]

# %% [markdown]
# ##### Analysis of Sales 2018

# %%
dfSalesProductsInventoryMergedGrouped2018 = dfSalesProductsInventoryMergedGrouped.loc[dfSalesProductsInventoryMergedGrouped['Year of Sales']==2018]  
dfSalesProductsInventoryMergedGrouped2018
# Out:
#        Year of Sales  \
# 7355            2018
# 7356            2018
# 7357            2018
# 7358            2018
# 7359            2018
# ...              ...
# 14366           2018
# 14367           2018
# 14368           2018
# 14369           2018
# 14370           2018
#
#        Month of Sales  \
# 7355                1
# 7356                1
# 7357                1
# 7358                1
# 7359                1
# ...               ...
# 14366               9
# 14367               9
# 14368               9
# 14369               9
# 14370               9
#
#       Month Name of Sales  \
# 7355                  Jan
# 7356                  Jan
# 7357                  Jan
# 7358                  Jan
# 7359                  Jan
# ...                   ...
# 14366                 Sep
# 14367                 Sep
# 14368                 Sep
# 14369                 Sep
# 14370                 Sep
#
#            Store City  \
# 7355   Aguascalientes
# 7356   Aguascalientes
# 7357   Aguascalientes
# 7358   Aguascalientes
# 7359   Aguascalientes
# ...               ...
# 14366       Zacatecas
# 14367       Zacatecas
# 14368       Zacatecas
# 14369       Zacatecas
# 14370       Zacatecas
#
#                 Product Name  \
# 7355           Action Figure
# 7356          Animal Figures
# 7357         Barrel O' Slime
# 7358        Classic Dominoes
# 7359               Colorbuds
# ...                      ...
# 14366               Playfoam
# 14367           Rubik's Cube
# 14368           Splash Balls
# 14369  Supersoaker Water Gun
# 14370             Teddy Bear
#
#        Product Cost ($)  \
# 7355           10989.00
# 7356            2197.80
# 7357            5166.04
# 7358            1933.58
# 7359            6458.76
# ...                 ...
# 14366           2094.75
# 14367          10955.91
# 14368           9228.45
# 14369           2769.69
# 14370           7385.28
#
#        Product Price ($)  \
# 7355            17589.00
# 7356             2857.80
# 7357            10358.04
# 7358             2417.58
# 7359            13850.76
# ...                  ...
# 14366            5769.75
# 14367           12173.91
# 14368           10383.45
# 14369            3462.69
# 14370            8729.28
#
#        Gross Profit ($)  \
# 7355            25450.0
# 7356             5090.0
# 7357            60062.0
# 7358             5599.0
# 7359            21378.0
# ...                 ...
# 14366           10500.0
# 14367           12180.0
# 14368           23100.0
# 14369            4620.0
# 14370           13440.0
#
#        Stock On Hand
# 7355            6600
# 7356             660
# 7357            5192
# 7358             484
# 7359            7392
# ...              ...
# 14366           3675
# 14367           1218
# 14368           1155
# 14369            693
# 14370           1344
#
# [7016 rows x 9 columns]

# %%
dfSalesProductsInventoryMerged['Year of Sales'].value_counts()
# Out:
# 2017    9242762
# 2018    8979316
# Name: Year of Sales, dtype: int64

# %% [markdown]
# Case when pandas , using filters ,qcut() oraz cut()  analyticsvidhya ,advanced transformation pandas, ETL pandas transformation plural sight
#
# -- put store city with the greatest amount of product and the least one, then union it by df
#
# -- look at links regarding pandas sql etc from my notes and use a few tip techniques from it.
#
# trends sales and stores f
#
# print somehitng in dataframe (in colourful ways)
#
#
# filter gross ssales higher than 10000 for example
# using pivottable!!

# %% [markdown]
# Further calculations:
# Total product revenue: £50
# Total production costs: £15
# Gross profit: 50-15 = £35
# Gross profit margin: 35/50 x 100 = 70
# Calculating GrossProfit % formula and other calculations

# %% [markdown]
# Calculations =  https://www.kaggle.com/datasets/mysarahmadbhat/toy-sales
# Sales & inventory data for a fictitious chain of toy stores in Mexico called Maven Toys, including information about products, stores, daily sales transactions, and current inventory levels at each location.
#
# Recommended Analysis
# Which product categories drive the biggest profits? Is this the same across store locations?
#
# Can you find any seasonal trends or patterns in the sales data?
#
# Are sales being lost with out-of-stock products at certain locations?
#
# How much money is tied up in inventory at the toy stores? How long will it last?
#
# calculations -> how many stories they have; how long they work (years); grouping date, which store provides the best profit; which products and visualise it, how many we have these product in stocks and which have the most. using advanced functions.
# https://sparkbyexamples.com/pandas/pandas-groupby-sum-examples/
#
# filter with gross profit to find it !! iloc etd where / query
#
# https://sparkbyexamples.com/pandas/pandas-groupby-count-examples/
